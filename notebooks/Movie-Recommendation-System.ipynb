# %%
from pyspark.sql.functions import *
from pyspark.sql import SparkSession
import findspark
import os
import pandas as pd

from ast import literal_eval

from stack_data.utils import truncate

findspark.init()

os.environ["PYSPARK_SUBMIT_ARGS"] = "--master local[2] pyspark-shell --jars C:\\Users\\09398\\PycharmProjects\\elasticsearch-spark-recommender\\elasticsearch-hadoop-8.17.0\\dist\\elasticsearch-spark-30_2.12-8.17.0.jar"

os.environ["PYSPARK_DRIVER_PYTHON"] = "jupyter"
os.environ["PYSPARK_DRIVER_PYTHON_OPTS"] = "notebook"
es_hadoop_jar = "C:\\Users\\09398\\PycharmProjects\\elasticsearch-spark-recommender\\elasticsearch-hadoop-8.17.0\\dist\\elasticsearch-spark-30_2.12-8.17.0.jar"

spark = SparkSession.builder \
    .appName("ElasticsearchIntegration") \
    .config("spark.speculation", "false") \
    .config("spark.jars", es_hadoop_jar) \
    .config("es.nodes", "http://localhost:9200") \
    .config("es.nodes.wan.only", "true") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "4g") \
    .config("spark.driver.maxResultSize", "2g") \
    .config("spark.memory.fraction", "0.8") \
    .config("spark.memory.storageFraction", "0.5") \
    .getOrCreate()

# %%
spark.catalog.clearCache()

# %%
PATH_TO_DATA = "../data/archive"

# %%
md = spark.read.csv(
    f"{PATH_TO_DATA}/movies_metadata.csv",
    header=True,
    inferSchema=True,
    multiLine=True,
    escape="\"",
    quote='"',
    sep=',',
    ignoreTrailingWhiteSpace=True,
    ignoreLeadingWhiteSpace=True
)
md.show(5)
# Out:
# +-----+---------------------+--------+--------------------+--------------------+-----+---------+-----------------+--------------------+--------------------+----------+--------------------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+
# |adult|belongs_to_collection|  budget|              genres|            homepage|   id|  imdb_id|original_language|      original_title|            overview|popularity|         poster_path|production_companies|production_countries|release_date|  revenue|runtime|    spoken_languages|  status|             tagline|               title|video|vote_average|vote_count|
# +-----+---------------------+--------+--------------------+--------------------+-----+---------+-----------------+--------------------+--------------------+----------+--------------------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+
# |False| {'id': 10194, 'na...|30000000|[{'id': 16, 'name...|http://toystory.d...|  862|tt0114709|               en|           Toy Story|Led by Woody, And...| 21.946943|/rhIRbceoE9lR4veE...|[{'name': 'Pixar ...|[{'iso_3166_1': '...|  1995-10-30|373554033|   81.0|[{'iso_639_1': 'e...|Released|                NULL|           Toy Story|false|         7.7|      5415|
# |False|                 NULL|65000000|[{'id': 12, 'name...|                NULL| 8844|tt0113497|               en|             Jumanji|When siblings Jud...| 17.015539|/vzmL6fP7aPKNKPRT...|[{'name': 'TriSta...|[{'iso_3166_1': '...|  1995-12-15|262797249|  104.0|[{'iso_639_1': 'e...|Released|Roll the dice and...|             Jumanji|false|         6.9|      2413|
# |False| {'id': 119050, 'n...|       0|[{'id': 10749, 'n...|                NULL|15602|tt0113228|               en|    Grumpier Old Men|A family wedding ...|   11.7129|/6ksm1sjKMFLbO7UY...|[{'name': 'Warner...|[{'iso_3166_1': '...|  1995-12-22|        0|  101.0|[{'iso_639_1': 'e...|Released|Still Yelling. St...|    Grumpier Old Men|false|         6.5|        92|
# |False|                 NULL|16000000|[{'id': 35, 'name...|                NULL|31357|tt0114885|               en|   Waiting to Exhale|Cheated on, mistr...|  3.859495|/16XOMpEaLWkrcPqS...|[{'name': 'Twenti...|[{'iso_3166_1': '...|  1995-12-22| 81452156|  127.0|[{'iso_639_1': 'e...|Released|Friends are the p...|   Waiting to Exhale|false|         6.1|        34|
# |False| {'id': 96871, 'na...|       0|[{'id': 35, 'name...|                NULL|11862|tt0113041|               en|Father of the Bri...|Just when George ...|  8.387519|/e64sOI48hQXyru7n...|[{'name': 'Sandol...|[{'iso_3166_1': '...|  1995-02-10| 76578911|  106.0|[{'iso_639_1': 'e...|Released|Just When His Wor...|Father of the Bri...|false|         5.7|       173|
# +-----+---------------------+--------+--------------------+--------------------+-----+---------+-----------------+--------------------+--------------------+----------+--------------------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+
# only showing top 5 rows

# %%
md = md.drop("adult", "belongs_to_collection", "homepage", "imdb_id", "original_language", "original_title", "poster_path",
             "production_countries", "status", "video", "spoken_languages", "production_companies", "revenue", "runtime", "budget")

# %%
md.show(5)
# Out:
# +--------------------+-----+--------------------+----------+------------+--------------------+--------------------+------------+----------+
# |              genres|   id|            overview|popularity|release_date|             tagline|               title|vote_average|vote_count|
# +--------------------+-----+--------------------+----------+------------+--------------------+--------------------+------------+----------+
# |[{'id': 16, 'name...|  862|Led by Woody, And...| 21.946943|  1995-10-30|                NULL|           Toy Story|         7.7|      5415|
# |[{'id': 12, 'name...| 8844|When siblings Jud...| 17.015539|  1995-12-15|Roll the dice and...|             Jumanji|         6.9|      2413|
# |[{'id': 10749, 'n...|15602|A family wedding ...|   11.7129|  1995-12-22|Still Yelling. St...|    Grumpier Old Men|         6.5|        92|
# |[{'id': 35, 'name...|31357|Cheated on, mistr...|  3.859495|  1995-12-22|Friends are the p...|   Waiting to Exhale|         6.1|        34|
# |[{'id': 35, 'name...|11862|Just when George ...|  8.387519|  1995-02-10|Just When His Wor...|Father of the Bri...|         5.7|       173|
# +--------------------+-----+--------------------+----------+------------+--------------------+--------------------+------------+----------+
# only showing top 5 rows

# %% [markdown]
# Xu ly cot genres: chuyen thanh list cac genres

# %%
from pyspark.sql.functions import col, from_json, expr
from pyspark.sql.types import ArrayType, StructType, StructField, StringType
genres_schema = ArrayType(StructType([
    StructField("id", StringType(), True),
    StructField("name", StringType(), True)
]))
md = md.withColumn("genres", from_json(col("genres"), genres_schema))
md = md.withColumn("genres", expr("transform(genres, x -> x.name)"))

md.show(5, truncate=False)
# Out:
# +----------------------------+-----+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+------------------------------------------------------------------------------+---------------------------+------------+----------+
# |genres                      |id   |overview                                                                                                                                                                                                                                                                                                                                                                                                   |popularity|release_date|tagline                                                                       |title                      |vote_average|vote_count|
# +----------------------------+-----+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+------------------------------------------------------------------------------+---------------------------+------------+----------+
# |[Animation, Comedy, Family] |862  |Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.                                                                                            |21.946943 |1995-10-30  |NULL                                                                          |Toy Story                  |7.7         |5415      |
# |[Adventure, Fantasy, Family]|8844 |When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures.|17.015539 |1995-12-15  |Roll the dice and unleash the excitement!                                     |Jumanji                    |6.9         |2413      |
# |[Romance, Comedy]           |15602|A family wedding reignites the ancient feud between next-door neighbors and fishing buddies John and Max. Meanwhile, a sultry Italian divorcée opens a restaurant at the local bait shop, alarming the locals who worry she'll scare the fish away. But she's less interested in seafood than she is in cooking up a hot time with Max.                                                                    |11.7129   |1995-12-22  |Still Yelling. Still Fighting. Still Ready for Love.                          |Grumpier Old Men           |6.5         |92        |
# |[Comedy, Drama, Romance]    |31357|Cheated on, mistreated and stepped on, the women are holding their breath, waiting for the elusive "good man" to break a string of less-than-stellar lovers. Friends and confidants Vannah, Bernie, Glo and Robin talk it all out, determined to find a better way to breathe.                                                                                                                             |3.859495  |1995-12-22  |Friends are the people who let you be yourself... and never let you forget it.|Waiting to Exhale          |6.1         |34        |
# |[Comedy]                    |11862|Just when George Banks has recovered from his daughter's wedding, he receives the news that she's pregnant ... and that George's wife, Nina, is expecting too. He was planning on selling their home, but that's a plan that -- like George -- will have to change with the arrival of both a grandchild and a kid of his own.                                                                             |8.387519  |1995-02-10  |Just When His World Is Back To Normal... He's In For The Surprise Of His Life!|Father of the Bride Part II|5.7         |173       |
# +----------------------------+-----+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+------------------------------------------------------------------------------+---------------------------+------------+----------+
# only showing top 5 rows

# %%
vote_counts = md.filter(col('vote_count').isNotNull()).select(
    col('vote_count').cast('int'))


vote_averages = md.filter(col('vote_average').isNotNull()).select(
    col('vote_average').cast('int'))

# %%
C = vote_averages.agg(avg('vote_average')).first()[0]
C
# Out:
# 5.244896612406511

# %%
m = vote_counts.approxQuantile('vote_count', [0.95], 0)[0]
m
# Out:
# 434.0

# %%
md = md.withColumn('release_date', to_date(col('release_date'), 'yyyy-MM-dd'))
md = md.withColumn('year', year(col('release_date')))
md.show(5)
# Out:
# +--------------------+-----+--------------------+----------+------------+--------------------+--------------------+------------+----------+----+
# |              genres|   id|            overview|popularity|release_date|             tagline|               title|vote_average|vote_count|year|
# +--------------------+-----+--------------------+----------+------------+--------------------+--------------------+------------+----------+----+
# |[Animation, Comed...|  862|Led by Woody, And...| 21.946943|  1995-10-30|                NULL|           Toy Story|         7.7|      5415|1995|
# |[Adventure, Fanta...| 8844|When siblings Jud...| 17.015539|  1995-12-15|Roll the dice and...|             Jumanji|         6.9|      2413|1995|
# |   [Romance, Comedy]|15602|A family wedding ...|   11.7129|  1995-12-22|Still Yelling. St...|    Grumpier Old Men|         6.5|        92|1995|
# |[Comedy, Drama, R...|31357|Cheated on, mistr...|  3.859495|  1995-12-22|Friends are the p...|   Waiting to Exhale|         6.1|        34|1995|
# |            [Comedy]|11862|Just when George ...|  8.387519|  1995-02-10|Just When His Wor...|Father of the Bri...|         5.7|       173|1995|
# +--------------------+-----+--------------------+----------+------------+--------------------+--------------------+------------+----------+----+
# only showing top 5 rows

# %%
qualified = md.filter((col('vote_count') >= m) & col('vote_count').isNotNull() & col('vote_average').isNotNull()) \
              .select('title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres')
qualified = qualified.withColumn('vote_count', col('vote_count').cast('int')) \
                     .withColumn('vote_average', col('vote_average').cast('int'))
shape = (qualified.count(), len(qualified.columns))
shape
# Out:
# (2274, 6)

# %%
from pyspark.sql.types import DoubleType, StructField


@udf(DoubleType())
def weighted_rating_udf(vote_count, vote_average):
    return (vote_count / (vote_count + m) * vote_average) + (m / (vote_count + m) * C)

# %%
qualified = qualified.withColumn('wr', weighted_rating_udf(
    col('vote_count'), col('vote_average')))

# %%
qualified = qualified.orderBy(col('wr').desc())
qualified.show(10)
# Out:
# +--------------------+----+----------+------------+----------+--------------------+------------------+
# |               title|year|vote_count|vote_average|popularity|              genres|                wr|
# +--------------------+----+----------+------------+----------+--------------------+------------------+
# |           Inception|2010|     14075|           8| 29.108149|[Action, Thriller...| 7.917588057742396|
# |     The Dark Knight|2008|     12269|           8|123.167259|[Drama, Action, C...| 7.905871457906355|
# |        Interstellar|2014|     11187|           8| 32.213481|[Adventure, Drama...| 7.897107402958818|
# |          Fight Club|1999|      9678|           8| 63.869599|             [Drama]| 7.881752880714441|
# |The Lord of the R...|2001|      8892|           8| 32.070725|[Adventure, Fanta...| 7.871786953654775|
# |        Pulp Fiction|1994|      8670|           8|140.950236|   [Thriller, Crime]| 7.868660493166128|
# |The Shawshank Red...|1994|      8358|           8| 51.645403|      [Drama, Crime]| 7.863999673542359|
# |The Lord of the R...|2003|      8226|           8| 29.324358|[Adventure, Fanta...|7.8619266893515505|
# |        Forrest Gump|1994|      8147|           8| 48.307194|[Comedy, Drama, R...| 7.860655533129522|
# |The Lord of the R...|2002|      7641|           8| 29.423537|[Adventure, Fanta...| 7.851923855081663|
# +--------------------+----+----------+------------+----------+--------------------+------------------+
# only showing top 10 rows

# %%
from pyspark.sql.types import StringType, ArrayType
gen_md = md.withColumn("genre", explode(col("genres")))
gen_md = gen_md.drop("genres")
gen_md.show(truncate=False)
# Out:
# +-----+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+------------------------------------------------------------------------------+---------------------------+------------+----------+----+---------+
# |id   |overview                                                                                                                                                                                                                                                                                                                                                                                                   |popularity|release_date|tagline                                                                       |title                      |vote_average|vote_count|year|genre    |
# +-----+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+------------------------------------------------------------------------------+---------------------------+------------+----------+----+---------+
# |862  |Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.                                                                                            |21.946943 |1995-10-30  |NULL                                                                          |Toy Story                  |7.7         |5415      |1995|Animation|
# |862  |Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.                                                                                            |21.946943 |1995-10-30  |NULL                                                                          |Toy Story                  |7.7         |5415      |1995|Comedy   |
# |862  |Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.                                                                                            |21.946943 |1995-10-30  |NULL                                                                          |Toy Story                  |7.7         |5415      |1995|Family   |
# |8844 |When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures.|17.015539 |1995-12-15  |Roll the dice and unleash the excitement!                                     |Jumanji                    |6.9         |2413      |1995|Adventure|
# |8844 |When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures.|17.015539 |1995-12-15  |Roll the dice and unleash the excitement!                                     |Jumanji                    |6.9         |2413      |1995|Fantasy  |
# |8844 |When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures.|17.015539 |1995-12-15  |Roll the dice and unleash the excitement!                                     |Jumanji                    |6.9         |2413      |1995|Family   |
# |15602|A family wedding reignites the ancient feud between next-door neighbors and fishing buddies John and Max. Meanwhile, a sultry Italian divorcée opens a restaurant at the local bait shop, alarming the locals who worry she'll scare the fish away. But she's less interested in seafood than she is in cooking up a hot time with Max.                                                                    |11.7129   |1995-12-22  |Still Yelling. Still Fighting. Still Ready for Love.                          |Grumpier Old Men           |6.5         |92        |1995|Romance  |
# |15602|A family wedding reignites the ancient feud between next-door neighbors and fishing buddies John and Max. Meanwhile, a sultry Italian divorcée opens a restaurant at the local bait shop, alarming the locals who worry she'll scare the fish away. But she's less interested in seafood than she is in cooking up a hot time with Max.                                                                    |11.7129   |1995-12-22  |Still Yelling. Still Fighting. Still Ready for Love.                          |Grumpier Old Men           |6.5         |92        |1995|Comedy   |
# |31357|Cheated on, mistreated and stepped on, the women are holding their breath, waiting for the elusive "good man" to break a string of less-than-stellar lovers. Friends and confidants Vannah, Bernie, Glo and Robin talk it all out, determined to find a better way to breathe.                                                                                                                             |3.859495  |1995-12-22  |Friends are the people who let you be yourself... and never let you forget it.|Waiting to Exhale          |6.1         |34        |1995|Comedy   |
# |31357|Cheated on, mistreated and stepped on, the women are holding their breath, waiting for the elusive "good man" to break a string of less-than-stellar lovers. Friends and confidants Vannah, Bernie, Glo and Robin talk it all out, determined to find a better way to breathe.                                                                                                                             |3.859495  |1995-12-22  |Friends are the people who let you be yourself... and never let you forget it.|Waiting to Exhale          |6.1         |34        |1995|Drama    |
# |31357|Cheated on, mistreated and stepped on, the women are holding their breath, waiting for the elusive "good man" to break a string of less-than-stellar lovers. Friends and confidants Vannah, Bernie, Glo and Robin talk it all out, determined to find a better way to breathe.                                                                                                                             |3.859495  |1995-12-22  |Friends are the people who let you be yourself... and never let you forget it.|Waiting to Exhale          |6.1         |34        |1995|Romance  |
# |11862|Just when George Banks has recovered from his daughter's wedding, he receives the news that she's pregnant ... and that George's wife, Nina, is expecting too. He was planning on selling their home, but that's a plan that -- like George -- will have to change with the arrival of both a grandchild and a kid of his own.                                                                             |8.387519  |1995-02-10  |Just When His World Is Back To Normal... He's In For The Surprise Of His Life!|Father of the Bride Part II|5.7         |173       |1995|Comedy   |
# |949  |Obsessive master thief, Neil McCauley leads a top-notch crew on various insane heists throughout Los Angeles while a mentally unstable detective, Vincent Hanna pursues him without rest. Each man recognizes and respects the ability and the dedication of the other even though they are aware their cat-and-mouse game may end in violence.                                                            |17.924927 |1995-12-15  |A Los Angeles Crime Saga                                                      |Heat                       |7.7         |1886      |1995|Action   |
# |949  |Obsessive master thief, Neil McCauley leads a top-notch crew on various insane heists throughout Los Angeles while a mentally unstable detective, Vincent Hanna pursues him without rest. Each man recognizes and respects the ability and the dedication of the other even though they are aware their cat-and-mouse game may end in violence.                                                            |17.924927 |1995-12-15  |A Los Angeles Crime Saga                                                      |Heat                       |7.7         |1886      |1995|Crime    |
# |949  |Obsessive master thief, Neil McCauley leads a top-notch crew on various insane heists throughout Los Angeles while a mentally unstable detective, Vincent Hanna pursues him without rest. Each man recognizes and respects the ability and the dedication of the other even though they are aware their cat-and-mouse game may end in violence.                                                            |17.924927 |1995-12-15  |A Los Angeles Crime Saga                                                      |Heat                       |7.7         |1886      |1995|Drama    |
# |949  |Obsessive master thief, Neil McCauley leads a top-notch crew on various insane heists throughout Los Angeles while a mentally unstable detective, Vincent Hanna pursues him without rest. Each man recognizes and respects the ability and the dedication of the other even though they are aware their cat-and-mouse game may end in violence.                                                            |17.924927 |1995-12-15  |A Los Angeles Crime Saga                                                      |Heat                       |7.7         |1886      |1995|Thriller |
# |11860|An ugly duckling having undergone a remarkable change, still harbors feelings for her crush: a carefree playboy, but not before his business-focused brother has something to say about it.                                                                                                                                                                                                                |6.677277  |1995-12-15  |You are cordially invited to the most surprising merger of the year.          |Sabrina                    |6.2         |141       |1995|Comedy   |
# |11860|An ugly duckling having undergone a remarkable change, still harbors feelings for her crush: a carefree playboy, but not before his business-focused brother has something to say about it.                                                                                                                                                                                                                |6.677277  |1995-12-15  |You are cordially invited to the most surprising merger of the year.          |Sabrina                    |6.2         |141       |1995|Romance  |
# |45325|A mischievous young boy, Tom Sawyer, witnesses a murder by the deadly Injun Joe. Tom becomes friends with Huckleberry Finn, a boy with no future and no family. Tom has to choose between honoring a friendship or honoring an oath because the town alcoholic is accused of the murder. Tom and Huck go through several adventures trying to retrieve evidence.                                           |2.561161  |1995-12-22  |The Original Bad Boys.                                                        |Tom and Huck               |5.4         |45        |1995|Action   |
# |45325|A mischievous young boy, Tom Sawyer, witnesses a murder by the deadly Injun Joe. Tom becomes friends with Huckleberry Finn, a boy with no future and no family. Tom has to choose between honoring a friendship or honoring an oath because the town alcoholic is accused of the murder. Tom and Huck go through several adventures trying to retrieve evidence.                                           |2.561161  |1995-12-22  |The Original Bad Boys.                                                        |Tom and Huck               |5.4         |45        |1995|Adventure|
# +-----+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+------------------------------------------------------------------------------+---------------------------+------------+----------+----+---------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col, mean, lit, when, expr
from pyspark.sql.types import DoubleType


def build_chart(genre, percentile=0.85):
    genre_df = gen_md.filter(col("genre") == genre)
    genre_df = genre_df.filter(
        col("vote_count").isNotNull() & col("vote_average").isNotNull())
    genre_df = genre_df.withColumn("vote_count", col("vote_count").cast("int"))
    genre_df = genre_df.withColumn(
        "vote_average", col("vote_average").cast("double"))
    C = genre_df.select(mean(col("vote_average"))).first()[0]
    m = genre_df.approxQuantile("vote_count", [percentile], 0.01)[0]
    qualified = genre_df.filter(col("vote_count") >= m).select(
        "title", "year", "vote_count", "vote_average", "popularity"
    )
    qualified = qualified.withColumn(
        "wr",
        (col("vote_count") / (col("vote_count") + lit(m)) * col("vote_average")) +
        (lit(m) / (col("vote_count") + lit(m)) * lit(C))
    )

    qualified = qualified.orderBy(col("wr").desc()).limit(250)

    return qualified

# %%
build_chart('Romance').show(5, truncate=False)
# Out:
# +---------------------------+----+----------+------------+----------+-----------------+
# |title                      |year|vote_count|vote_average|popularity|wr               |
# +---------------------------+----+----------+------------+----------+-----------------+
# |Dilwale Dulhania Le Jayenge|1995|661       |9.1         |34.457024 |8.728219129758896|
# |Your Name.                 |2016|1030      |8.5         |34.461252 |8.296609741176281|
# |Forrest Gump               |1994|8147      |8.2         |48.307194 |8.17553435204354 |
# |Cinema Paradiso            |1988|834       |8.2         |14.177005 |7.980635350403461|
# |La La Land                 |2016|4745      |7.9         |19.681686 |7.863516929316707|
# +---------------------------+----+----------+------------+----------+-----------------+
# only showing top 5 rows

# %% [markdown]
# \*\*Content-based recommendation system

# %%
links = spark.read.csv(
    f"{PATH_TO_DATA}/links_small.csv",
    header=True,
    inferSchema=True,
    multiLine=True,
    quote='"',
    sep=',',
    ignoreTrailingWhiteSpace=True,  #
    ignoreLeadingWhiteSpace=True
)
links.show(5)
# Out:
# +-------+------+------+
# |movieId|imdbId|tmdbId|
# +-------+------+------+
# |      1|114709|   862|
# |      2|113497|  8844|
# |      3|113228| 15602|
# |      4|114885| 31357|
# |      5|113041| 11862|
# +-------+------+------+
# only showing top 5 rows

# %%
links = links.filter(col('tmdbId').isNotNull()) \
    .select(col('tmdbId').cast('int'))

# %%
md = md.withColumn('id', col('id').cast('int'))

# %%
md = md.filter(col('id').isNotNull())

# %% [markdown]
# Movie description Based Recommender

# %% [markdown]
# \*Handle Meta data of movies

# %%
keywords = spark.read.csv(
    f"{PATH_TO_DATA}/keywords.csv",
    header=True,
    inferSchema=True,
    multiLine=True,
    escape="\"",
    quote='"',
    sep=',',
    ignoreTrailingWhiteSpace=True,
    ignoreLeadingWhiteSpace=True
)

# %%
credits_pd = pd.read_csv(f"{PATH_TO_DATA}/credits.csv")
crew_struct = StructType([
    StructField("job", StringType(), True),
    StructField("name", StringType(), True)
])

credits_pd['crew'] = credits_pd['crew'].apply(literal_eval)
credits_pd['crew'] = credits_pd['crew'].apply(
    lambda x: [{'job': i['job'], 'name': i['name']} for i in x])
credits_pd['cast'] = credits_pd['cast'].apply(literal_eval)
credits_pd['cast'] = credits_pd['cast'].apply(
    lambda x: [{'name': i['name']} for i in x])
credits_pd['cast'] = credits_pd['cast'].apply(
    lambda x: x[:3] if len(x) > 3 else x)
credits_pd['id'] = credits_pd['id'].astype(int)

credits = spark.createDataFrame(credits_pd)

# %%
credits.show(5, truncate=False)
# Out:
# +-------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |cast                                                                           |crew                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# +-------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[{name -> Tom Hanks}, {name -> Tim Allen}, {name -> Don Rickles}]              |[{name -> John Lasseter, job -> Director}, {name -> Joss Whedon, job -> Screenplay}, {name -> Andrew Stanton, job -> Screenplay}, {name -> Joel Cohen, job -> Screenplay}, {name -> Alec Sokolow, job -> Screenplay}, {name -> Bonnie Arnold, job -> Producer}, {name -> Ed Catmull, job -> Executive Producer}, {name -> Ralph Guggenheim, job -> Producer}, {name -> Steve Jobs, job -> Executive Producer}, {name -> Lee Unkrich, job -> Editor}, {name -> Ralph Eggleston, job -> Art Direction}, {name -> Robert Gordon, job -> Editor}, {name -> Mary Helen Leasman, job -> Foley Editor}, {name -> Kim Blanchette, job -> Animation}, {name -> Marilyn McCoppen, job -> ADR Editor}, {name -> Randy Newman, job -> Orchestrator}, {name -> Dale E. Grahn, job -> Color Timer}, {name -> Robin Cooper, job -> CG Painter}, {name -> John Lasseter, job -> Original Story}, {name -> Pete Docter, job -> Original Story}, {name -> Joe Ranft, job -> Original Story}, {name -> Patsy Bouge, job -> Post Production Supervisor}, {name -> Norm DeCarlo, job -> Sculptor}, {name -> Ash Brannon, job -> Animation Director}, {name -> Randy Newman, job -> Music}, {name -> Roman Figun, job -> Layout}, {name -> Don Davis, job -> Orchestrator}, {name -> James Flamberg, job -> Music Editor}, {name -> Mary Beth Smith, job -> Negative Cutter}, {name -> Rick Mackay, job -> Negative Cutter}, {name -> Susan Bradley, job -> Title Designer}, {name -> William Reeves, job -> Supervising Technical Director}, {name -> Randy Newman, job -> Songs}, {name -> Andrew Stanton, job -> Original Story}, {name -> Pete Docter, job -> Supervising Animator}, {name -> Gary Rydstrom, job -> Sound Designer}, {name -> Karen Robert Jackson, job -> Production Supervisor}, {name -> Chris Montan, job -> Executive Music Producer}, {name -> Rich Quade, job -> Animation Director}, {name -> Michael Berenstein, job -> Animation}, {name -> Colin Brady, job -> Animation}, {name -> Davey Crockett Feiten, job -> Animation}, {name -> Angie Glocka, job -> Animation}, {name -> Rex Grignon, job -> Animation}, {name -> Tom K. Gurney, job -> Animation}, {name -> Jimmy Hayward, job -> Animation}, {name -> Hal T. Hickel, job -> Animation}, {name -> Karen Kiser, job -> Animation}, {name -> Anthony B. LaMolinara, job -> Animation}, {name -> Guionne Leroy, job -> Animation}, {name -> Bud Luckey, job -> Animation}, {name -> Les Major, job -> Animation}, {name -> Glenn McQueen, job -> Animation}, {name -> Mark Oftedal, job -> Animation}, {name -> Jeff Pidgeon, job -> Animation}, {name -> Jeff Pratt, job -> Animation}, {name -> Steve Rabatich, job -> Animation}, {name -> Roger Rose, job -> Animation}, {name -> Steve Segal, job -> Animation}, {name -> Doug Sheppeck, job -> Animation}, {name -> Alan Sperling, job -> Animation}, {name -> Doug Sweetland, job -> Animation}, {name -> David Tart, job -> Animation}, {name -> Ken Willard, job -> Animation}, {name -> Thomas Porter, job -> Visual Effects Supervisor}, {name -> Mark Thomas Henne, job -> Visual Effects}, {name -> Oren Jacob, job -> Visual Effects}, {name -> Darwyn Peachey, job -> Visual Effects}, {name -> Mitch Prater, job -> Visual Effects}, {name -> Brian M. Rosen, job -> Visual Effects}, {name -> Sharon Calahan, job -> Lighting Supervisor}, {name -> Galyn Susman, job -> Lighting Supervisor}, {name -> William Cone, job -> CG Painter}, {name -> Shelley Daniels Lekven, job -> Sculptor}, {name -> Bob Pauley, job -> Character Designer}, {name -> Bud Luckey, job -> Character Designer}, {name -> Andrew Stanton, job -> Character Designer}, {name -> William Cone, job -> Character Designer}, {name -> Steve Johnson, job -> Character Designer}, {name -> Dan Haskett, job -> Character Designer}, {name -> Tom Holloway, job -> Character Designer}, {name -> Jean Gillmore, job -> Character Designer}, {name -> Desirée Mourad, job -> Layout}, {name -> Kelly O'Connell, job -> Set Dresser}, {name -> Sonoko Konishi, job -> Set ...
# |[{name -> Robin Williams}, {name -> Jonathan Hyde}, {name -> Kirsten Dunst}]   |[{name -> Larry J. Franco, job -> Executive Producer}, {name -> Jonathan Hensleigh, job -> Screenplay}, {name -> James Horner, job -> Original Music Composer}, {name -> Joe Johnston, job -> Director}, {name -> Robert Dalva, job -> Editor}, {name -> Nancy Foy, job -> Casting}, {name -> Kyle Balda, job -> Animation Supervisor}, {name -> James D. Bissell, job -> Production Design}, {name -> Scott Kroopf, job -> Producer}, {name -> Ted Field, job -> Executive Producer}, {name -> Robert W. Cort, job -> Executive Producer}, {name -> Thomas E. Ackerman, job -> Director of Photography}, {name -> Chris van Allsburg, job -> Novel}, {name -> William Teitler, job -> Producer}, {name -> Greg Taylor, job -> Screenplay}, {name -> Jim Strain, job -> Screenplay}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# |[{name -> Walter Matthau}, {name -> Jack Lemmon}, {name -> Ann-Margret}]       |[{name -> Howard Deutch, job -> Director}, {name -> Mark Steven Johnson, job -> Characters}, {name -> Mark Steven Johnson, job -> Writer}, {name -> Jack Keller, job -> Sound Recordist}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# |[{name -> Whitney Houston}, {name -> Angela Bassett}, {name -> Loretta Devine}]|[{name -> Forest Whitaker, job -> Director}, {name -> Ronald Bass, job -> Screenplay}, {name -> Ronald Bass, job -> Producer}, {name -> Ezra Swerdlow, job -> Producer}, {name -> Deborah Schindler, job -> Producer}, {name -> Terry McMillan, job -> Screenplay}, {name -> Terry McMillan, job -> Executive Producer}, {name -> Terry McMillan, job -> Novel}, {name -> Kenneth Edmonds, job -> Original Music Composer}, {name -> Caron K, job -> Producer}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# |[{name -> Steve Martin}, {name -> Diane Keaton}, {name -> Martin Short}]       |[{name -> Alan Silvestri, job -> Original Music Composer}, {name -> Elliot Davis, job -> Director of Photography}, {name -> Nancy Meyers, job -> Screenplay}, {name -> Nancy Meyers, job -> Producer}, {name -> Albert Hackett, job -> Screenplay}, {name -> Charles Shyer, job -> Director}, {name -> Adam Bernardi, job -> Editor}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# +-------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 5 rows

# %%
from pyspark.sql.functions import transform, expr, filter
credits = credits.withColumn(
    'director',
    expr("filter(crew, x -> x.job = 'Director')")
)
credits = credits.withColumn(
    'director',
    expr("transform(director, x -> x.name)")
)
credits = credits.withColumn("cast", expr("transform(cast, x -> x.name)"))

# %%
credits = credits.withColumn('id', col('id').cast('int'))
keywords = keywords.withColumn('id', col('id').cast('int'))

# %%
credits = credits.withColumn(
    'director',
    expr("transform(director, x -> array_repeat(x, 3))")
)

# %%
keywords_schema = ArrayType(StructType([
    StructField("id", StringType(), True),
    StructField("name", StringType(), True)
]))
keywords = keywords.withColumn(
    'keywords', from_json(col('keywords'), keywords_schema))
keywords = keywords.withColumn(
    'keywords', expr("transform(keywords, x -> x.name)"))

# %%
from pyspark.sql.types import ArrayType, StringType
from pyspark.sql.functions import udf
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer('english')


@udf(returnType=ArrayType(StringType()))
def process_keywords(keywords_array):
    if keywords_array is None:
        return []

    processed = [str.lower(k.replace(" ", "")) for k in keywords_array]
    stemmed = [stemmer.stem(k) for k in processed]
    return sorted(list(set(stemmed)))


keywords = keywords.withColumn("keywords", process_keywords(col("keywords")))

# %%
md = md.join(credits, md['id'] == credits['id'], 'left').drop(credits['id'])
md = md.join(keywords, md['id'] == keywords['id'], 'left').drop(keywords['id'])
md = md.join(links, md['id'] == links['tmdbId'])
md = md.withColumn('tagline', coalesce(col('tagline').cast('string'), lit('')))
md = md.withColumn('overview', coalesce(
    col('overview').cast('string'), lit('')))
md = md.withColumn('description', concat(
    col('tagline'), lit(' '), col('overview')))

# %%
md.show(5, truncate=True)
# Out:
# +--------------------+---+--------------------+----------+------------+--------------------+--------------+------------+----------+----+--------------------+--------------------+--------------------+--------------------+------+--------------------+
# |              genres| id|            overview|popularity|release_date|             tagline|         title|vote_average|vote_count|year|                cast|                crew|            director|            keywords|tmdbId|         description|
# +--------------------+---+--------------------+----------+------------+--------------------+--------------+------------+----------+----+--------------------+--------------------+--------------------+--------------------+------+--------------------+
# |     [Crime, Comedy]|  5|It's Ted the Bell...|  9.026586|  1995-12-09|Twelve outrageous...|    Four Rooms|         6.5|       539|1995|[Tim Roth, Antoni...|[{name -> Combust...|[[Allison Anders,...|[bet, episodefilm...|     5|Twelve outrageous...|
# |[Action, Thriller...|  6|While racing to a...|  5.538671|  1993-10-15|Don't move. Don't...|Judgment Night|         6.4|        79|1993|[Emilio Estevez, ...|[{name -> Stephen...|[[Stephen Hopkins...|[boxingmatch, chi...|     6|Don't move. Don't...|
# | [Animation, Family]| 12|Nemo, an adventur...| 25.497794|  2003-05-30|There are 3.7 tri...|  Finding Nemo|         7.6|      6292|2003|[Albert Brooks, E...|[{name -> Andrew ...|[[Andrew Stanton,...|[aftercreditsstin...|    12|There are 3.7 tri...|
# |[Comedy, Drama, R...| 13|A man with a low ...| 48.307194|  1994-07-06|The world will ne...|  Forrest Gump|         8.2|      8147|1994|[Tom Hanks, Robin...|[{name -> Robert ...|[[Robert Zemeckis...|[ampute, basedonn...|    13|The world will ne...|
# |    [Mystery, Drama]| 15|Newspaper magnate...| 15.811921|  1941-04-30|      It's Terrific!|  Citizen Kane|         8.0|      1244|1941|[Orson Welles, Jo...|[{name -> Orson W...|[[Orson Welles, O...|[artcollector, ba...|    15|It's Terrific! Ne...|
# +--------------------+---+--------------------+----------+------------+--------------------+--------------+------------+----------+----+--------------------+--------------------+--------------------+--------------------+------+--------------------+
# only showing top 5 rows

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(hosts="http://localhost:9200")
es.info(pretty=True)
# Out:
# ObjectApiResponse({'name': '4bbae3288639', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'dsCurIfHRImh4-bX_WtMsA', 'version': {'number': '8.10.2', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '6d20dd8ce62365be9b1aca96427de4622e970e9e', 'build_date': '2023-09-19T08:16:24.564900370Z', 'build_snapshot': False, 'lucene_version': '9.7.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})

# %%
VECTOR_DIM = 20
VECTOR_META_DIM = 384
create_ratings = {
    "mappings": {
        "properties": {
            "timestamp": {
                "type": "date"
            },
            "userId": {
                "type": "integer"
            },
            "movieId": {
                "type": "integer"
            },
            "rating": {
                "type": "double"
            }
        }
    }
}
create_users = {
    "mappings": {
        "properties": {
            "userId": {
                "type": "integer"
            },
            "model_factor": {
                "type": "dense_vector",
                "dims": VECTOR_DIM
            },
            "model_version": {
                "type": "keyword"
            },
            "model_timestamp": {
                "type": "date"
            }
        }
    }
}

create_movies = {
    "mappings": {
        "properties": {
            "movieId": {
                "type": "integer"
            },
            "year": {
                "type": "date",
                "format": "year"
            },
            "title": {
                "type": "text",
                "analyzer": "english",
                "fields": {
                    "keyword": {
                        "type": "keyword"
                    }
                }
            },
            "tmdbId": {
                "type": "keyword"
            },
            "vote_count": {
                "type": "integer"
            },
            "vote_average": {
                "type": "double"
            },
            "popularity": {
                "type": "double"
            },
            "description": {
                "type": "text",
                "analyzer": "english",
                "fields": {
                    "keyword": {
                        "type": "keyword"
                    }
                }
            },
            "meta_factor": {
                "type": "dense_vector",
                "dims": VECTOR_META_DIM
            },
            "model_factor": {
                "type": "dense_vector",
                "dims": VECTOR_DIM
            },
            "model_version": {
                "type": "keyword"
            },
            "model_timestamp": {
                "type": "date"
            }
        }
    }
}


def delete_index(index_name):
    if es.indices.exists(index=index_name):
        es.indices.delete(index=index_name)
        print(f"Deleted index: {index_name}")


delete_index("ratings")
delete_index("users")
delete_index("movies")
res_ratings = es.indices.create(index="ratings", body=create_ratings)
res_users = es.indices.create(index="users", body=create_users)
res_movies = es.indices.create(index="movies", body=create_movies)

print("Created indices:")
print(res_ratings)
print(res_users)
print(res_movies)
# Out:
# Deleted index: ratings
# Deleted index: users
# Deleted index: movies
# Created indices:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'ratings'}
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'users'}
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'movies'}

# %%
ratings = spark.read.csv(
    f"{PATH_TO_DATA}/ratings_small.csv",
    header=True,
    inferSchema=True,
    multiLine=True,
    quote='"',
    sep=',',
    ignoreTrailingWhiteSpace=True,
    ignoreLeadingWhiteSpace=True
)

# %%
md = md.withColumn('director', expr("transform(flatten(director), x -> x)"))

# %%
insert = md.withColumn("meta_data", concat_ws(
    " ",
    concat_ws(" ", col("keywords")),
    concat_ws(" ", col("cast")),
    concat_ws("", col("director")),
    concat_ws(" ", col("genres"))
))

# %%
insert.show(5)
# Out:
# +--------------------+---+--------------------+----------+------------+--------------------+-------------------+------------+----------+----+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+
# |              genres| id|            overview|popularity|release_date|             tagline|              title|vote_average|vote_count|year|                cast|                crew|            director|            keywords|tmdbId|         description|           meta_data|
# +--------------------+---+--------------------+----------+------------+--------------------+-------------------+------------+----------+----+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+
# |     [Drama, Comedy]|  3|An episode in the...|   2.29211|  1986-10-16|                    |Shadows in Paradise|         7.1|        35|1986|[Matti Pellonpää,...|[{name -> Aki Kau...|[Aki Kaurismäki, ...|[garbag, helsinki...|     3| An episode in th...|garbag helsinki i...|
# |     [Crime, Comedy]|  5|It's Ted the Bell...|  9.026586|  1995-12-09|Twelve outrageous...|         Four Rooms|         6.5|       539|1995|[Tim Roth, Antoni...|[{name -> Combust...|[Allison Anders, ...|[bet, episodefilm...|     5|Twelve outrageous...|bet episodefilm h...|
# |[Action, Thriller...|  6|While racing to a...|  5.538671|  1993-10-15|Don't move. Don't...|     Judgment Night|         6.4|        79|1993|[Emilio Estevez, ...|[{name -> Stephen...|[Stephen Hopkins,...|[boxingmatch, chi...|     6|Don't move. Don't...|boxingmatch chica...|
# | [Animation, Family]| 12|Nemo, an adventur...| 25.497794|  2003-05-30|There are 3.7 tri...|       Finding Nemo|         7.6|      6292|2003|[Albert Brooks, E...|[{name -> Andrew ...|[Andrew Stanton, ...|[aftercreditsstin...|    12|There are 3.7 tri...|aftercreditssting...|
# |[Comedy, Drama, R...| 13|A man with a low ...| 48.307194|  1994-07-06|The world will ne...|       Forrest Gump|         8.2|      8147|1994|[Tom Hanks, Robin...|[{name -> Robert ...|[Robert Zemeckis,...|[ampute, basedonn...|    13|The world will ne...|ampute basedonnov...|
# +--------------------+---+--------------------+----------+------------+--------------------+-------------------+------------+----------+----+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+
# only showing top 5 rows

# %%
movies_data_deduplicated = insert.dropDuplicates(["id"])

# %%
movies_data_deduplicated = movies_data_deduplicated.withColumn(
    "movieId", col("id"))

# %%
movies_data_deduplicated.show(10, truncate=False)
# Out:
# +----------------------------+---+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------+------------+----------+----+-------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |genres                      |id |overview                                                                                                                                                                                                                                                                                                                                                                                                                           |popularity|release_date|tagline                                                                                                                                                    |title                                                 |vote_average|vote_count|year|cast                                             |crew                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# +----------------------------+---+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------+------------+----------+----+-------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[Crime, Comedy]             |5  |It's Ted the Bellhop's first night on the job...and the hotel's very unusual guests are about to place him in some outrageous predicaments. It seems that this evening's room service is serving up one unbelievable happening after another.                                                                                                                                                                                      |9.026586  |1995-12-09  |Twelve outrageous guests. Four scandalous requests. And one lone bellhop, in his first day on the job, who's in for the wildest New year's Eve of his life.|Four Rooms                                            |6.5         |539       |1995|[Tim Roth, Antonio Banderas, Jennifer Beals]     |[{name -> Combustible Edison, job -> Original Music Composer}, {name -> Gary Frutkoff, job -> Production Design}, {name -> Lance Brown, job -> Sound Designer}, {name -> Allison Anders, job -> Director}, {name -> Alexandre Rockwell, job -> Director}, {name -> Robert Rodriguez, job -> Director}, {name -> Quentin Tarantino, job -> Director}, {name -> Lawrence Bender, job -> Producer}, {name -> Quentin Tarantino, job -> Executive Producer}, {name -> Alexandre Rockwell, job -> Executive Producer}, {name -> Russell Gray, job -> Casting}, {name -> Mayne Berke, job -> Art Direction}, {name -> Sara Andrews, job -> Set Decoration}, {name -> Allison Anders, job -> Writer}, {name -> Alexandre Rockwell, job -> Writer}, {name -> Robert Rodriguez, job -> Writer}, {name -> Quentin Tarantino, job -> Writer}, {name -> Rodrigo García, job -> Director of Photography}, {name -> Guillermo Navarro, job -> Director of Photography}, {name -> Phil Parmet, job -> Director of Photography}, {name -> Andrzej Sekula, job -> Director of Photography}, {name -> Margaret Goodspeed, job -> Editor}, {name -> Elena Maganini, job -> Editor}, {name -> Sally Menke, job -> Editor}, {name -> Robert Rodriguez, job -> Editor}, {name -> David Gertz, job -> Foley}, {name -> Paul Hellerman, job -> Co-Producer}, {name -> Scott Lambert, job -> Co-Producer}, {name -> Heidi Vogel, job -> Co-Producer}, {name -> Karyn Rachtman, job -> Music Supervisor}, {name -> Susan L. Bertram, job -> Costume Design}, {name -> Mary Claire Hannan, job -> Costume Design}, {name -> Marisol Jiménez, job -> Art Department Coordinator}, {name -> Brian Markey, job -> Construction Coordinator}, {name -> Ray Maxwell, job -> Construction Foreman}, {name -> Marc Gillson, job -> Lead Painter}, {name -> Carlos A. Chavez, job -> Painter}, {name -> T.D. Donnelly, job -> Standby Painter}, {name -> Ziad Doueiri, job -> First Assistant Camera}, {name -> Rick Stribling, job -> Key Grip}, {name -> Elizabeth Bolden, job -> Grip}, {name -> Jonathan Brown, job -> Steadicam Operator}, {name -> Jacqueline Aronson, job -> Costume Supervisor}, {name -> Thomas G. Marquez, job -> Costume Supervisor}, {name -> Orlando, job -> Hairstylist}, {name -> Ermahn Ospina, job -> Key Hair Stylist}, {name -> Paul Starr, job -> Makeup Artist}, {name -> James C. Beeson, job -> Carpenter}, {name -> Sissy Boyd, job -> Choreographer}, {name -> Derek Hurd, job -> Craft Service}, {name -> Darrell Dubovsky, job -> Driver}, {name -> Ben Parker, job -> Post Production Assistant}, {name -> Lynda Reiss, job -> Property Master}, {name -> Nick Roberts, job -> Security}, {name -> Patrice Carbaugh, job -> Set Medic}, {name -> Ben Parker, job -> Set Production Assistant}, {name -> Paul Taglianetti, job -> Special Effects Coordinator}, {name -> Michael Boyce Harris, job -> Stand In}, {name -> Dotti Thompson, job -> Transportation Captain}, {name -> P. Gerald Knight, job -> Transportation Coordinator}, {name -> Debbie Hayn-Cass, job -> Unit Production Manager}, {name -> Nancy Willen, job -> Unit Publicist}, {name -> Douglas Aarniokoski, job -> First Assistant Director}, {name -> Fernando Altschul, job -> First Assistant Director}, {name -> Jayne-Ann Tenggren, job -> Script Supervisor}, {name -> Mike  ...
# |[Action, Thriller, Crime]   |6  |While racing to a boxing match, Frank, Mike, John and Rey get more than they bargained for. A wrong turn lands them directly in the path of Fallon, a vicious, wise-cracking drug lord. After accidentally witnessing Fallon murder a disloyal henchman, the four become his unwilling prey in a savage game of cat &amp; mouse as they are mercilessly stalked through the urban jungle in this taut suspense drama               |5.538671  |1993-10-15  |Don't move. Don't whisper. Don't even breathe.                                                                                                             |Judgment Night                                        |6.4         |79        |1993|[Emilio Estevez, Cuba Gooding Jr., Denis Leary]  |[{name -> Stephen Hopkins, job -> Director}, {name -> Lewis Colick, job -> Screenplay}, {name -> Gene Levy, job -> Producer}, {name -> Alan Silvestri, job -> Original Music Composer}, {name -> Peter Levy, job -> Director of Photography}, {name -> Tim Wellburn, job -> Editor}, {name -> Christopher Mollo, job -> Associate Producer}, {name -> Kris Wiseman McIntyre, job -> Associate Producer}, {name -> Lloyd Segan, job -> Executive Producer}, {name -> Marilyn Vance, job -> Executive Producer}, {name -> Lewis Colick, job -> Story}, {name -> Jere Cunningham, job -> Story}, {name -> Joseph C. Nemec III, job -> Production Design}, {name -> Dan Olexiewicz, job -> Art Direction}, {name -> John M. Dwyer, job -> Set Decoration}, {name -> Marilyn Vance, job -> Costume Design}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# |[Animation, Family]         |12 |Nemo, an adventurous young clownfish, is unexpectedly taken from his Great Barrier Reef home to a dentist's office aquarium. It's up to his worrisome father Marlin and a friendly but forgetful fish Dory to bring Nemo home -- meeting vegetarian sharks, surfer dude turtles, hypnotic jellyfish, hungry seagulls, and more along the way.                                                                                      |25.497794 |2003-05-30  |There are 3.7 trillion fish in the ocean. They're looking for one.                                                                                         |Finding Nemo                                          |7.6         |6292      |2003|[Albert Brooks, Ellen DeGeneres, Alexander Gould]|[{name -> Andrew Stanton, job -> Screenplay}, {name -> Andrew Stanton, job -> Director}, {name -> Andrew Stanton, job -> Original Story}, {name -> Lee Unkrich, job -> Supervising Film Editor}, {name -> Lee Unkrich, job -> Co-Director}, {name -> Graham Walters, job -> Producer}, {name -> Bob Peterson, job -> Screenplay}, {name -> David Reynolds, job -> Screenplay}, {name -> John Lasseter, job -> Executive Producer}, {name -> David Ian Salter, job -> Editor}, {name -> Thomas Newman, job -> Original Music Composer}, {name -> Gary Rydstrom, job -> Sound Designer}, {name -> Gary Rydstrom, job -> Supervising Sound Editor}, {name -> Gary Rydstrom, job -> Sound Re-Recording Mixer}, {name -> Bill Bernstein, job -> Music Editor}, {name -> Ralph Eggleston, job -> Production Design}, {name -> Dominique Louis, job -> Visual Development}, {name -> Glenn McQueen, job -> In Memory Of}, {name -> Mary Hidalgo, job -> Casting}, {name -> Marcia Gwendolyn Jones, job -> Production Supervisor}, {name -> Nathan Stanton, job -> Story}, {name -> Geefwee Boedoe, job -> Visual Development}, {name -> Ricky Nierva, job -> Art Direction}, {name -> Angus MacLane, job -> Animation}, {name -> Glenn Kim, job -> CG Painter}, {name -> Laura Phillips, job -> CG Painter}, {name -> Jamie Frye, job -> CG Painter}, {name -> Yvonne Herbst, job -> CG Painter}, {name -> Robin Cooper, job -> Art Direction}, {name -> Randy Berrett, job -> Art Direction}, {name -> Jerome Ranft, job -> Sculptor}, {name -> Carter Goodrich, job -> Visual Development}, {name -> Peter DeSeve, job -> Visual Development}, {name -> Andrea Warren, job -> CG Painter}, {name -> Jeremy Lasky, job -> Director of Photography}, {name -> David Eisenmann, job -> CG Supervisor}, {name -> Alan Barillaro, job -> Animation Director}, {name -> Andrew Gordon, job -> Animation}, {name -> Andrew L. Schmidt, job -> Animation}, {name -> Paul Mendoza, job -> Fix Animator}, {name -> Jenni Tsoi, job -> Animation Manager}, {name -> Gabrielle Siegel, job -> Editorial Production Assistant}, {name -> Katherine Ringgold, job -> Second Film Editor}, {name -> Axel Geddes, job -> First Assistant Editor}, {name -> E.J. Holowicki, job -> Sound Effects Editor}, {name -> Brian Green, job -> CG Supervisor}, {name -> Anthony A. Apodaca, job -> CG Supervisor}, {name -> Steve May, job -> CG Supervisor}, {name -> Louis Rivera, job -> Camera Supervisor}, {name -> Paul Cichocki, job -> Post Production Supervisor}, {name -> John Hazelton, job -> Projection}, {name -> Michael Silvers, job -> Supervising Sound Editor}, {name -> Shannon Mills, job -> Sound Effects Editor}, {name -> Dee Selby, job -> Sound Design Assistant}, {name -> Sharon Calahan, job -> Director of Photography}, {name -> Teresa Eckton, job -> Sound Effects Editor}, {name -> Peter Sohn, job -> Story}, {name -> Jim Capobianco, job -> Story}, {name -> Stan Webb, job -> Second Film Editor}, {name -> Kevin Reher, job -> Casting}, {name -> Matthew Jon Beck, job -> Casting}, {name -> Bruce Morris, job -> Story}, {name -> Lindsey Collins, job -> Production Manager}, {name -> Jinko Gotoh, job -> Associate Producer}, {name -> Bosco Ng, job -> Storyboard}, {name -> Dylan Brown, job -> Supervising Animator}, {name -> Mark A. Walsh,  ...
# |[Comedy, Drama, Romance]    |13 |A man with a low IQ has accomplished great things in his life and been present during significant historic events - in each case, far exceeding what anyone imagined he could do. Yet, despite all the things he has attained, his one true love eludes him. 'Forrest Gump' is the story of a man who rose above his challenges, and who proved that determination, courage, and love are more important than ability.             |48.307194 |1994-07-06  |The world will never be the same, once you've seen it through the eyes of Forrest Gump.                                                                    |Forrest Gump                                          |8.2         |8147      |1994|[Tom Hanks, Robin Wright, Gary Sinise]           |[{name -> Robert Zemeckis, job -> Director}, {name -> Wendy Finerman, job -> Producer}, {name -> Steve Tisch, job -> Producer}, {name -> Steve Starkey, job -> Producer}, {name -> Don Burgess, job -> Director of Photography}, {name -> Alan Silvestri, job -> Original Music Composer}, {name -> Arthur Schmidt, job -> Editor}, {name -> Eric Roth, job -> Screenplay}, {name -> Winston Groom, job -> Novel}, {name -> Ellen Lewis, job -> Casting}, {name -> Joanna Johnston, job -> Costume Design}, {name -> Rick Carter, job -> Production Design}, {name -> Leslie McDonald, job -> Art Direction}, {name -> William James Teegarden, job -> Art Direction}, {name -> Nancy Haigh, job -> Set Decoration}, {name -> Hazel Catmull, job -> Hairstylist}, {name -> William A. Kohout, job -> Hairstylist}, {name -> Susan Schuler-Page, job -> Hairstylist}, {name -> Jay Cannistraci, job -> Makeup Artist}, {name -> Rick Sharp, job -> Makeup Artist}, {name -> Kacy Magedman, job -> Art Department Coordinator}, {name -> Wendy Richardson, job -> Art Department Coordinator}, {name -> Steve Arnold, job -> Assistant Art Director}, {name -> Linda Berger, job -> Assistant Art Director}, {name -> Tony Fanning, job -> Assistant Art Director}, {name -> Jeff Passanante, job -> Construction Coordinator}, {name -> Robin L. Miller, job -> Property Master}, {name -> Stephen I. Erdberg, job -> Property Master}, {name -> Daniel J. Gillooly, job -> Greensman}, {name -> Hugo Herrera, job -> Greensman}, {name -> Kevin Mangan, job -> Greensman}, {name -> Dan Ondrejko, job -> Greensman}, {name -> Paige Augustine, job -> Leadman}, {name -> Claire Gaul, job -> Leadman}, {name -> Robert Greenfield, job -> Leadman}, {name -> Chris L. Spellman, job -> Leadman}, {name -> James C. Feng, job -> Set Designer}, {name -> Erin Kemp, job -> Set Designer}, {name -> Elizabeth Lapp, job -> Set Designer}, {name -> Lauren E. Polizzi, job -> Set Designer}, {name -> Sue Fox, job -> ADR & Dubbing}, {name -> Tom Barwick, job -> Foley}, {name -> Dennie Thorpe, job -> Foley}, {name -> Claire Sanfilippo, job -> Dialogue Editor}, {name -> Dianna Stirpe, job -> Dialogue Editor}, {name -> Ewa Sztompke, job -> Dialogue Editor}, {name -> E. Larry Oatfield, job -> Sound Effects Editor}, {name -> Robert Shoup, job -> Sound Effects Editor}, {name -> Dennis S. Sands, job -> Sound Re-Recording Mixer}, {name -> Randy Thom, job -> Sound Re-Recording Mixer}, {name -> Gloria S. Borders, job -> Supervising Sound Editor}, {name -> George Murphy, job -> CG Supervisor}, {name -> Stephen Rosenbaum, job -> CG Supervisor}, {name -> Doug Chiang, job -> Visual Effects Art Director}, {name -> Debbie Denise, job -> Visual Effects Producer}, {name -> Debbie Denise, job -> Visual Effects Editor}, {name -> Michael McGovern, job -> Visual Effects Editor}, {name -> Ken Ralston, job -> Visual Effects Supervisor}, {name -> Bud Davis, job -> Stunt Coordinator}, {name -> David M. Dunlap, job -> Second Unit Cinematographer}, {name -> Chris Squires, job -> Camera Operator}, {name -> Phillip V. Caruso, job -> Still Photographer}, {name -> Dan Bronson, job -> Costume Supervisor}, {name -> Pamela Wise, job -> Costume Supervisor}, {name -> Patricia Bercsi, job -> Set Costumer}, {name -> Rudolph ...
# |[Mystery, Drama]            |15 |Newspaper magnate, Charles Foster Kane is taken from his mother as a boy and made the ward of a rich industrialist. As a result, every well-meaning, tyrannical or self-destructive move he makes for the rest of his life appears in some way to be a reaction to that deeply wounding event.                                                                                                                                     |15.811921 |1941-04-30  |It's Terrific!                                                                                                                                             |Citizen Kane                                          |8.0         |1244      |1941|[Orson Welles, Joseph Cotten, Dorothy Comingore] |[{name -> Orson Welles, job -> Director}, {name -> Orson Welles, job -> Producer}, {name -> Richard Baer, job -> Producer}, {name -> George Schaefer, job -> Executive Producer}, {name -> Bernard Herrmann, job -> Original Music Composer}, {name -> Gregg Toland, job -> Director of Photography}, {name -> Robert Wise, job -> Editor}, {name -> Van Nest Polglase, job -> Art Direction}, {name -> Edward Stevenson, job -> Costume Design}, {name -> Vernon L. Walker, job -> Special Effects}, {name -> Orson Welles, job -> Screenplay}, {name -> Herman J. Mankiewicz, job -> Screenplay}, {name -> Roger Q. Denny, job -> Writer}, {name -> John Houseman, job -> Writer}, {name -> Mollie Kent, job -> Writer}, {name -> Tom Steele, job -> Stunts}, {name -> Mel Berns, job -> Makeup Department Head}, {name -> Rufus Le Maire, job -> Casting}, {name -> Darrell Silvera, job -> Set Decoration}, {name -> Layne Britton, job -> Makeup Artist}, {name -> Maurice Seiderman, job -> Makeup Artist}, {name -> Pandro S. Berman, job -> Executive In Charge Of Production}, {name -> J.R. Crone, job -> Production Manager}, {name -> Lee S. Marcus, job -> Post Production Supervisor}, {name -> Edward Donahue, job -> Assistant Director}, {name -> Fred Fleck, job -> Second Assistant Director}, {name -> George Cave, job -> Color Timer}, {name -> John Houseman, job -> Editorial Manager}, {name -> Mark Robson, job -> Assistant Editor}, {name -> Elizabeth McGaffey, job -> Researcher}, {name -> Alexander Kahle, job -> Still Photographer}, {name -> Vic Jones, job -> Gaffer}, {name -> Phil Stern, job -> Still Photographer}, {name -> John Aalberg, job -> Supervising Sound Editor}, {name -> Clem Portman, job -> Sound Re-Recording Mixer}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# |[Drama, Crime, Music]       |16 |Selma, a Czech immigrant on the verge of blindness, struggles to make ends meet for herself and her son, who has inherited the same genetic disorder and will suffer the same fate without an expensive operation. When life gets too difficult, Selma learns to cope through her love of musicals, escaping life's troubles - even if just for a moment - by dreaming up little numbers to the rhythmic beats of her surroundings.|10.684806 |2000-05-17  |You don't need eyes to see.                                                                                                                                |Dancer in the Dark                                    |7.7         |392       |2000|[Björk, Catherine Deneuve, David Morse]          |[{name -> Lars von Trier, job -> Director}, {name -> Vibeke Windeløv, job -> Producer}, {name -> Peter Aalbæk Jensen, job -> Executive Producer}, {name -> Friðrik Þór Friðriksson, job -> Producer}, {name -> Finn Gjerdrum, job -> Producer}, {name -> Mogens Glad, job -> Producer}, {name -> Anja Grafers, job -> Producer}, {name -> Torleif Hauge, job -> Producer}, {name -> Tero Kaukomaa, job -> Producer}, {name -> Poul Erik Lindeborg, job -> Producer}, {name -> Els Vandevorst, job -> Producer}, {name -> Robby Müller, job -> Director of Photography}, {name -> François Gédigier, job -> Editor}, {name -> Molly Malene Stensgaard, job -> Editor}, {name -> Avy Kaufman, job -> Casting}, {name -> Karl Júlíusson, job -> Production Design}, {name -> Manon Rasmussen, job -> Costume Design}, {name -> Kristian Eidnes Andersen, job -> Sound Designer}, {name -> Peter Grant, job -> Art Direction}, {name -> Lars von Trier, job -> Writer}, {name -> Michelle Crane, job -> Hairstylist}, {name -> John Nollet, job -> Hairstylist}, {name -> Cédric Gérard, job -> Makeup Artist}, {name -> Ursula Rödel, job -> Makeup Artist}, {name -> Vincent Paterson, job -> Choreographer}, {name -> Liz Miller, job -> Unit Publicist}, {name -> Malte Forssell, job -> Line Producer}, {name -> Lars Jönsson, job -> Co-Executive Producer}, {name -> Leo Pescarolo, job -> Producer}, {name -> Marianne Slot, job -> Co-Executive Producer}, {name -> Björk, job -> Original Music Composer}, {name -> Anders Barlebo, job -> Unit Production Manager}, {name -> Joakim Höglund, job -> Unit Production Manager}, {name -> Anders Refn, job -> Assistant Director}, {name -> Caroline Sascha Cogez, job -> Assistant Director}, {name -> Jesper Lorents, job -> Property Master}, {name -> Fabio D'Amico, job -> ADR & Dubbing}, {name -> Pétur Einarsson, job -> Dialogue Editor}, {name -> Guy Sigsworth, job -> Sound}, {name -> Ad Stoop, job -> Boom Operator}, {name -> Per Streit, job -> Sound Designer}, {name -> Mark Kenna, job -> Dolby Consultant}, {name -> Stig Günther, job -> Stunts}, {name -> Frank Berger, job -> Gaffer}, {name -> David Koskas, job -> Still Photographer}, {name -> Morten Nybø, job -> Electrician}, {name -> Eric Kress, job -> Cinematography}, {name -> Sedsel Andersen, job -> Cinematography}, {name -> Harri Sipilä, job -> Electrician}, {name -> Lars von Trier, job -> Camera Operator}, {name -> Louize Nissen, job -> Assistant Costume Designer}, {name -> Christine Ekstrand, job -> Post Production Assistant}, {name -> Peter Hjorth, job -> Additional Editing}, {name -> Yvan Lucas, job -> Color Timer}, {name -> Isobel Griffiths, job -> Sound}, {name -> Malini Ahlberg, job -> Production Coordinator}, {name -> Andrea F. Cannistraci, job -> Legal Services}, {name -> Jonas Frederiksen, job -> Production Controller}, {name -> Peter Garde, job -> Finance}, {name -> Sean-Michael Smith, job -> Dialect Coach}, {name -> Carsten Sparwath, job -> Production Office Assistant}, {name -> James Wilson, job -> Production Accountant}]                                                                                                                                                                                                                                     ...
# |[Drama, Science Fiction]    |19 |In a futuristic city sharply divided between the working class and the city planners, the son of the city's mastermind falls in love with a working class prophet who predicts the coming of a savior to mediate their differences.                                                                                                                                                                                                |14.487867 |1927-01-10  |There can be no understanding between the hands and the brain unless the heart acts as mediator.                                                           |Metropolis                                            |8.0         |666       |1927|[Brigitte Helm, Alfred Abel, Gustav Fröhlich]    |[{name -> Erich Pommer, job -> Producer}, {name -> Fritz Lang, job -> Director}, {name -> Gottfried Huppertz, job -> Original Music Composer}, {name -> Fritz Lang, job -> Editor}, {name -> Karl Freund, job -> Director of Photography}, {name -> Günther Rittau, job -> Director of Photography}, {name -> Walter Ruttmann, job -> Director of Photography}, {name -> Aenne Willkomm, job -> Costume Design}, {name -> Edgar G. Ulmer, job -> Set Designer}, {name -> Karl Vollbrecht, job -> Art Direction}, {name -> Erich Kettelhut, job -> Art Direction}, {name -> Otto Hunte, job -> Art Direction}, {name -> Fritz Lang, job -> Screenplay}, {name -> Thea von Harbou, job -> Screenplay}, {name -> Walter Schulze-Mittendorff, job -> Sculptor}, {name -> Ernst Kunstmann, job -> Special Effects}, {name -> Konstantin Irmen-Tschet, job -> Special Effects}, {name -> Eugen Schüfftan, job -> Visual Effects}, {name -> Robert Baberske, job -> First Assistant Camera}, {name -> Horst von Harbou, job -> Still Photographer}, {name -> Frank Strobel, job -> Music Editor}, {name -> Thea von Harbou, job -> Novel}, {name -> Slatan Dudow, job -> Assistant Director}, {name -> Otto Hunte, job -> Set Designer}, {name -> Erich Kettelhut, job -> Set Designer}, {name -> Karl Vollbrecht, job -> Set Designer}, {name -> Karl Freund, job -> Camera Operator}, {name -> Günther Rittau, job -> Camera Operator}, {name -> Otto Harzner, job -> Original Music Composer}, {name -> Frank Strobel, job -> Conductor}, {name -> Erich Holder, job -> Production Office Assistant}, {name -> Erich Kettelhut, job -> Production Office Assistant}, {name -> Hans Taussig, job -> Production Office Assistant}, {name -> Rudi George, job -> Production Artist}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# |[Drama, Romance]            |20 |A Pedro Almodovar production in which a fatally ill mother with only two months to live creates a list of things she wants to do before she dies with out telling her family of her illness.                                                                                                                                                                                                                                       |10.310508 |2003-03-07  |                                                                                                                                                           |My Life Without Me                                    |7.2         |78        |2003|[Sarah Polley, Amanda Plummer, Scott Speedman]   |[{name -> Isabel Coixet, job -> Director}, {name -> Esther García, job -> Producer}, {name -> Gordon McLennan, job -> Producer}, {name -> Nanci Kincaid, job -> Author}, {name -> Jean-Claude Larrieu, job -> Director of Photography}, {name -> Lisa Robison, job -> Editor}, {name -> Alfonso Vilallonga, job -> Original Music Composer}, {name -> Agustín Almodóvar, job -> Executive Producer}, {name -> Pedro Almodóvar, job -> Executive Producer}, {name -> Heidi Levitt, job -> Casting}, {name -> Monika Mikkelsen, job -> Casting}, {name -> Shelley Bolton, job -> Art Direction}, {name -> Katia Stano, job -> Costume Design}, {name -> Manuel Corrales, job -> Sound Designer}, {name -> Viorel Ghiocel, job -> Sound Designer}, {name -> Patrick Ghislain, job -> Sound Designer}, {name -> Albert Manera, job -> Sound Designer}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# |[Adventure, Fantasy, Action]|22 |Jack Sparrow, a freewheeling 17th-century pirate who roams the Caribbean Sea, butts heads with a rival pirate bent on pillaging the village of Port Royal. When the governor's daughter is kidnapped, Sparrow decides to help the girl's love save her. But their seafaring mission is hardly simple.                                                                                                                              |47.326665 |2003-07-09  |Prepare to be blown out of the water.                                                                                                                      |Pirates of the Caribbean: The Curse of the Black Pearl|7.5         |7191      |2003|[Johnny Depp, Geoffrey Rush, Orlando Bloom]      |[{name -> Dariusz Wolski, job -> Director of Photography}, {name -> Klaus Badelt, job -> Original Music Composer}, {name -> Gore Verbinski, job -> Director}, {name -> Jerry Bruckheimer, job -> Producer}, {name -> Brian Morris, job -> Production Design}, {name -> Ted Elliott, job -> Screenstory}, {name -> Terry Rossio, job -> Screenstory}, {name -> Stuart Beattie, job -> Screenstory}, {name -> Jay Wolpert, job -> Screenstory}, {name -> Jennifer Alessi, job -> Casting}, {name -> Ronna Kress, job -> Casting}, {name -> Stephen E. Rivkin, job -> Editor}, {name -> Arthur Schmidt, job -> Editor}, {name -> Craig Wood, job -> Editor}, {name -> Ted Elliott, job -> Screenplay}, {name -> Terry Rossio, job -> Screenplay}, {name -> Ve Neill, job -> Makeup Department Head}, {name -> Penny Rose, job -> Costume Design}, {name -> Tom Waite, job -> Stunts}, {name -> Derek R. Hill, job -> Art Direction}, {name -> Michael Powels, job -> Art Direction}, {name -> Cedric Nicolas-Troyan, job -> Visual Effects}, {name -> Paul Deason, job -> Executive Producer}, {name -> Bruce Hendricks, job -> Executive Producer}, {name -> Chad Oman, job -> Executive Producer}, {name -> Pat Sandston, job -> Associate Producer}, {name -> Mike Stenson, job -> Executive Producer}, {name -> James E. Tocci, job -> Art Direction}, {name -> Donald B. Woodruff, job -> Art Direction}, {name -> Larry Dias, job -> Set Decoration}, {name -> Carla S. Nemec, job -> Art Department Coordinator}, {name -> Robert A. Blackburn, job -> Construction Coordinator}, {name -> Stephen Howard, job -> Construction Foreman}, {name -> Craig B. Ayers Sr., job -> Greensman}, {name -> P. Scott Bailey, job -> Leadman}, {name -> Alan James, job -> Painter}, {name -> Darek Gogol, job -> Production Illustrator}, {name -> Gene Darnell, job -> Set Designer}, {name -> Patrick Loungway, job -> Additional Photography}, {name -> Chris Haarhoff, job -> Camera Operator}, {name -> Jeff Sturgill, job -> Camera Technician}, {name -> Dennis Rogers, job -> First Assistant Camera}, {name -> Andy Bertelson, job -> Grip}, {name -> David B. Nowell, job -> Aerial Director of Photography}, {name -> David Luckenbach, job -> Steadicam Operator}, {name -> Elliott Marks, job -> Still Photographer}, {name -> Peter Manno, job -> Underwater Camera}, {name -> Alexa M. Stone, job -> Assistant Costume Designer}, {name -> Martin Samuel, job -> Hair Designer}, {name -> Susan Carol Schwary, job -> Hairstylist}, {name -> Jane Aull, job -> Makeup Artist}, {name -> Toby Bronson, job -> Set Costumer}, {name -> G. Roger Abell, job -> Set Dresser}, {name -> Bob Kretschmer, job -> Wigmaker}, {name -> Slamm Andrews, job -> Additional Music}, {name -> Harry Lu, job -> Armorer}, {name -> Mick Simpson, job -> Carpenter}, {name -> JoAnn Fregalette Jansen, job -> Choreographer}, {name -> Lea Anderson, job -> Craft Service}, {name -> Barbara Berkery, job -> Dialect Coach}, {name -> Gregory D. Liegey, job -> Digital Effects Supervisor}, {name -> Steve De Leon, job -> Driver}, {name -> Mark Connelly, job -> Loader}, {name -> Dylan Quirt, job -> Post Production Assistant}, {name -> Tami Goldman, job -> Post Production Supervisor}, {name -> Michael Betz, job -> Production Office Assistant}, {name -> F ...
# |[Drama]                     |26 |Eyal, an Israeli Mossad agent, is given the mission to track down and kill the very old Alfred Himmelman, an ex-Nazi officer, who might still be alive. Pretending to be a tourist guide, he befriends his grandson Axel, in Israel to visit his sister Pia. The two men set out on a tour of the country during which, Axel challenges Eyal's values.                                                                             |1.709996  |2004-02-05  |He was trained to hate until he met the enemy.                                                                                                             |Walk on Water                                         |6.5         |20        |2004|[Lior Ashkenazi, Knut Berger, Caroline Peters]   |[{name -> Ivri Lider, job -> Original Music Composer}, {name -> Eytan Fox, job -> Director}, {name -> Amir Harel, job -> Producer}, {name -> Gal Uchovsky, job -> Producer}, {name -> Gal Uchovsky, job -> Author}, {name -> Yosef Grunfeld, job -> Editor}, {name -> Tobias Hochstein, job -> Director of Photography}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# +----------------------------+---+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------+------------+----------+----+-------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 10 rows

# %%
from sentence_transformers import SentenceTransformer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import numpy as np
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
model = SentenceTransformer('all-MiniLM-L6-v2')
VECTOR_META_DIM = 384


def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [t for t in tokens if t not in stop_words]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(t) for t in tokens]
    return tokens


def get_weighted_meta_embeddings(movie_data):
    weights = {
        'description': 0.35,
        'title': 0.25,
        'meta_data': 0.4,
    }
    vector_dim = model.get_sentence_embedding_dimension()
    embeddings = {field: np.zeros(vector_dim) for field in weights}
    for field in weights:
        if field in movie_data and movie_data[field]:
            if isinstance(movie_data[field], list):
                text = ' '.join(movie_data[field])
            else:
                text = str(movie_data[field])
            tokens = preprocess_text(text)
            if len(tokens) <= 256:
                field_embedding = model.encode(' '.join(tokens))
            else:
                chunks = [tokens[i:i + 256]
                          for i in range(0, len(tokens), 256)]
                chunk_embeddings = [model.encode(
                    ' '.join(chunk)) for chunk in chunks]
                field_embedding = np.mean(chunk_embeddings, axis=0)

            embeddings[field] = field_embedding * weights[field]
    meta_embedding = np.sum(list(embeddings.values()), axis=0)
    return meta_embedding


def process_meta_features(movies_df):
    meta_features = []
    for _, movie in movies_df.iterrows():
        meta_embedding = get_weighted_meta_embeddings(movie)
        meta_features.append({
            'movieId': movie['movieId'],
            'meta_factor': meta_embedding.tolist()
        })
    return spark.createDataFrame(meta_features)


movies_data_deduplicated.show(5)
meta_features_df = process_meta_features(movies_data_deduplicated.toPandas())
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\09398\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\09398\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\09398\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\09398\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# +--------------------+---+--------------------+----------+------------+--------------------+--------------+------------+----------+----+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+-------+
# |              genres| id|            overview|popularity|release_date|             tagline|         title|vote_average|vote_count|year|                cast|                crew|            director|            keywords|tmdbId|         description|           meta_data|movieId|
# +--------------------+---+--------------------+----------+------------+--------------------+--------------+------------+----------+----+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+-------+
# |     [Crime, Comedy]|  5|It's Ted the Bell...|  9.026586|  1995-12-09|Twelve outrageous...|    Four Rooms|         6.5|       539|1995|[Tim Roth, Antoni...|[{name -> Combust...|[Allison Anders, ...|[bet, episodefilm...|     5|Twelve outrageous...|bet episodefilm h...|      5|
# |[Action, Thriller...|  6|While racing to a...|  5.538671|  1993-10-15|Don't move. Don't...|Judgment Night|         6.4|        79|1993|[Emilio Estevez, ...|[{name -> Stephen...|[Stephen Hopkins,...|[boxingmatch, chi...|     6|Don't move. Don't...|boxingmatch chica...|      6|
# | [Animation, Family]| 12|Nemo, an adventur...| 25.497794|  2003-05-30|There are 3.7 tri...|  Finding Nemo|         7.6|      6292|2003|[Albert Brooks, E...|[{name -> Andrew ...|[Andrew Stanton, ...|[aftercreditsstin...|    12|There are 3.7 tri...|aftercreditssting...|     12|
# |[Comedy, Drama, R...| 13|A man with a low ...| 48.307194|  1994-07-06|The world will ne...|  Forrest Gump|         8.2|      8147|1994|[Tom Hanks, Robin...|[{name -> Robert ...|[Robert Zemeckis,...|[ampute, basedonn...|    13|The world will ne...|ampute basedonnov...|     13|
# |    [Mystery, Drama]| 15|Newspaper magnate...| 15.811921|  1941-04-30|      It's Terrific!|  Citizen Kane|         8.0|      1244|1941|[Orson Welles, Jo...|[{name -> Orson W...|[Orson Welles, Or...|[artcollector, ba...|    15|It's Terrific! Ne...|artcollector bank...|     15|
# +--------------------+---+--------------------+----------+------------+--------------------+--------------+------------+----------+----+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+-------+
# only showing top 5 rows

# %%
meta_features_df.show(5)
# Out:
# +--------------------+-------+
# |         meta_factor|movieId|
# +--------------------+-------+
# |[-0.0079367812722...|      5|
# |[0.01152728311717...|      6|
# |[-0.0574968159198...|     12|
# |[-0.0772633850574...|     13|
# |[-0.0738316923379...|     15|
# +--------------------+-------+
# only showing top 5 rows

# %%
movies_data_to_indexed = movies_data_deduplicated.join(
    meta_features_df, on='movieId', how='inner').drop(meta_features_df['movieId'])

# %%
movies_data_to_indexed = movies_data_to_indexed.drop("meta_data")

# %%
movies_data_to_indexed.write.format("es").option(
    "es.mapping.id", "movieId").save("movies")
num_movies_df = movies_data_to_indexed.count()
num_movies_es = es.count(index="movies")['count']
print("Movie DF count: {}".format(num_movies_df))
print("ES index count: {}".format(num_movies_es))
# Out:
# Movie DF count: 9082
# ES index count: 9082

# %%
es.indices.refresh(index="movies")
# Out:
# ObjectApiResponse({'_shards': {'total': 2, 'successful': 1, 'failed': 0}})

# %%
ratings = ratings.filter(col('movieId').isin(
    [i.movieId for i in movies_data_deduplicated.select("movieId").collect()]))

# %%
ratings.write.format("es").save("ratings")
num_ratings_es = es.count(index="ratings")['count']
num_ratings_df = ratings.count()
print("Dataframe count: {}".format(num_ratings_df))
print("ES index count:  {}".format(num_ratings_es))
# Out:
# Dataframe count: 32131
# ES index count:  32131

# %%
# Get all ratings from Elasticsearch index
ratings_es = spark.read.format("es").load("ratings")
ratings_es.show(5)
# Out:
# +-------+------+--------------------+------+
# |movieId|rating|           timestamp|userId|
# +-------+------+--------------------+------+
# |   1371|   2.5|1970-01-15 22:12:...|     1|
# |   1405|   1.0|1970-01-15 22:12:...|     1|
# |   2105|   4.0|1970-01-15 22:12:...|     1|
# |   2193|   2.0|1970-01-15 22:12:...|     1|
# |   2294|   2.0|1970-01-15 22:12:...|     1|
# +-------+------+--------------------+------+
# only showing top 5 rows

# %%
from pyspark.ml.recommendation import ALS

# %%
null_counts = ratings.select(
    [count(when(col(c).isNull(), c)).alias(c) for c in ratings.columns])
null_counts.show()
total_rows = ratings.count()
print(f"Total number of rows: {total_rows}")
# Out:
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     0|      0|     0|        0|
# +------+-------+------+---------+
#
# Total number of rows: 32131

# %%
from itertools import product
from pyspark.sql.functions import row_number, rand
from pyspark.sql import Window
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql.functions import col
from sklearn.metrics import ndcg_score
import numpy as np


def evaluate_recommendations(model, test_data):
    if not model or not test_data:
        print("intput error")
        return None
    test_data_clean = test_data.na.drop()
    predictions = model.transform(test_data_clean)
    predictions = predictions.filter(col("prediction").isNotNull())

    evaluator = RegressionEvaluator(
        metricName="rmse",
        labelCol="rating",
        predictionCol="prediction"
    )
    rmse = evaluator.evaluate(predictions)

    evaluator = RegressionEvaluator(
        metricName="mae",
        labelCol="rating",
        predictionCol="prediction"
    )
    mae = evaluator.evaluate(predictions)
    k = 10
    true_ratings = predictions.select(
        "rating").rdd.flatMap(lambda x: x).collect()
    pred_ratings = predictions.select(
        "prediction").rdd.flatMap(lambda x: x).collect()
    if not true_ratings or not pred_ratings:
        ndcg = 0
    else:
        ndcg = ndcg_score([true_ratings], [pred_ratings], k=k)

    return {
        "RMSE": rmse,
        "MAE": mae,
        "NDCG@10": ndcg
    }


def improved_als_model(ratings, rank=20, regParam=0.1, alpha=1.0):
    ratings_clean = ratings.na.drop()
    als = ALS(
        userCol="userId",
        itemCol="movieId",
        ratingCol="rating",
        rank=rank,
        regParam=regParam,
        implicitPrefs=True,
        alpha=alpha,
        nonnegative=True,
        seed=54,
        coldStartStrategy="drop"
    )
    model = als.fit(ratings_clean)
    return model


def tune_hyperparameters(ratings):
    reg_params = [0.01, 0.1, 1.0]
    alphas = [1, 10, 40]
    ranks = [10, 20, 30]
    best_metrics = None
    best_params = None
    for reg, alpha, rank in product(reg_params, alphas, ranks):
        print(f"regParam={reg}, alpha={alpha}, rank={rank}")
        train, test = ratings.randomSplit([0.8, 0.2])
        model = improved_als_model(
            train,
            rank=rank,
            regParam=reg,
            alpha=alpha
        )
        metrics = evaluate_recommendations(model, test)
        if (best_metrics is None or
                metrics["RMSE"] < best_metrics["RMSE"]):
            best_metrics = metrics
            best_params = {
                "regParam": reg,
                "alpha": alpha,
                "rank": rank
            }
    return best_params, best_metrics


best_params, best_metrics = tune_hyperparameters(ratings_es)
print("Best parameters:", best_params)
print("Best metrics:", best_metrics)
final_model = improved_als_model(
    ratings_es,
    rank=rank,
    regParam=best_params["regParam"],
    alpha=best_params["alpha"]
)
# Out:
# regParam=0.01, alpha=1, rank=10
# regParam=0.01, alpha=1, rank=20
# regParam=0.01, alpha=1, rank=30
# regParam=0.01, alpha=10, rank=10
# regParam=0.01, alpha=10, rank=20
# regParam=0.01, alpha=10, rank=30
# regParam=0.01, alpha=40, rank=10
# regParam=0.01, alpha=40, rank=20
# regParam=0.01, alpha=40, rank=30
# regParam=0.1, alpha=1, rank=10
# regParam=0.1, alpha=1, rank=20
# regParam=0.1, alpha=1, rank=30
# regParam=0.1, alpha=10, rank=10
# regParam=0.1, alpha=10, rank=20
# regParam=0.1, alpha=10, rank=30
# regParam=0.1, alpha=40, rank=10
# regParam=0.1, alpha=40, rank=20
# regParam=0.1, alpha=40, rank=30
# regParam=1.0, alpha=1, rank=10
# regParam=1.0, alpha=1, rank=20
# regParam=1.0, alpha=1, rank=30
# regParam=1.0, alpha=10, rank=10
# regParam=1.0, alpha=10, rank=20
# regParam=1.0, alpha=10, rank=30
# regParam=1.0, alpha=40, rank=10
# regParam=1.0, alpha=40, rank=20
# regParam=1.0, alpha=40, rank=30
# Best parameters: {'regParam': 0.1, 'alpha': 40, 'rank': 10}
# Best metrics: {'RMSE': 2.9019140886576165, 'MAE': 2.7127171438015525, 'NDCG@10': np.float64(0.8054428981659402)}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\apps\spark-3.5.3-bin-hadoop3\python\pyspark\ml\param\__init__.py:503, in Params._set(self, **kwargs)
#     502 try:
# --> 503     value = p.typeConverter(value)
#     504 except TypeError as e:
#
# File C:\apps\spark-3.5.3-bin-hadoop3\python\pyspark\ml\param\__init__.py:224, in TypeConverters.toInt(value)
#     223 else:
# --> 224     raise TypeError("Could not convert %s to int" % value)
#
# TypeError: Could not convert <function rank at 0x0000023A3A598A60> to int
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 91
#      89 print("Best parameters:", best_params)
#      90 print("Best metrics:", best_metrics)
# ---> 91 final_model = improved_als_model(
#      92     ratings_es,
#      93     rank=rank,
#      94     regParam=best_params["regParam"],
#      95     alpha=best_params["alpha"]
#      96 )
#
# Cell In[13], line 48, in improved_als_model(ratings, rank, regParam, alpha)
#      46 def improved_als_model(ratings, rank=20, regParam=0.1, alpha=1.0):
#      47     ratings_clean = ratings.na.drop()
# ---> 48     als = ALS(
#      49         userCol="userId",
#      50         itemCol="movieId",
#      51         ratingCol="rating",
#      52         rank=rank,
#      53         regParam=regParam,
#      54         implicitPrefs=True,
#      55         alpha=alpha,
#      56         nonnegative=True,
#      57         seed=54,
#      58         coldStartStrategy="drop"
#      59     )
#      60     model = als.fit(ratings_clean)
#      61     return model
#
# File C:\apps\spark-3.5.3-bin-hadoop3\python\pyspark\__init__.py:139, in keyword_only.<locals>.wrapper(self, *args, **kwargs)
#     137     raise TypeError("Method %s forces keyword arguments." % func.__name__)
#     138 self._input_kwargs = kwargs
# --> 139 return func(self, **kwargs)
#
# File C:\apps\spark-3.5.3-bin-hadoop3\python\pyspark\ml\recommendation.py:401, in ALS.__init__(self, rank, maxIter, regParam, numUserBlocks, numItemBlocks, implicitPrefs, alpha, userCol, itemCol, seed, ratingCol, nonnegative, checkpointInterval, intermediateStorageLevel, finalStorageLevel, coldStartStrategy, blockSize)
#     399 self._java_obj = self._new_java_obj("org.apache.spark.ml.recommendation.ALS", self.uid)
#     400 kwargs = self._input_kwargs
# --> 401 self.setParams(**kwargs)
#
# File C:\apps\spark-3.5.3-bin-hadoop3\python\pyspark\__init__.py:139, in keyword_only.<locals>.wrapper(self, *args, **kwargs)
#     137     raise TypeError("Method %s forces keyword arguments." % func.__name__)
#     138 self._input_kwargs = kwargs
# --> 139 return func(self, **kwargs)
#
# File C:\apps\spark-3.5.3-bin-hadoop3\python\pyspark\ml\recommendation.py:435, in ALS.setParams(self, rank, maxIter, regParam, numUserBlocks, numItemBlocks, implicitPrefs, alpha, userCol, itemCol, seed, ratingCol, nonnegative, checkpointInterval, intermediateStorageLevel, finalStorageLevel, coldStartStrategy, blockSize)
#     426 """
#     427 setParams(self, \\*, rank=10, maxIter=10, regParam=0.1, numUserBlocks=10, \
#     428          numItemBlocks=10, implicitPrefs=False, alpha=1.0, userCol="user", itemCol="item", \
#    (...)
#     432 Sets params for ALS.
#     433 """
#     434 kwargs = self._input_kwargs
# --> 435 return self._set(**kwargs)
#
# File C:\apps\spark-3.5.3-bin-hadoop3\python\pyspark\ml\param\__init__.py:505, in Params._set(self, **kwargs)
#     503             value = p.typeConverter(value)
#     504         except TypeError as e:
# --> 505             raise TypeError('Invalid param value given for param "%s". %s' % (p.name, e))
#     506     self._paramMap[p] = value
#     507 return self
#
# TypeError: Invalid param value given for param "rank". Could not convert <function rank at 0x0000023A3A598A60> to int

# %%
final_model.userFactors.show(5)
final_model.itemFactors.show(5)
# Out:
# +---+--------------------+
# | id|            features|
# +---+--------------------+
# | 10|[0.0, 0.0, 0.3113...|
# | 20|[0.6109069, 0.0, ...|
# | 30|[0.28762525, 0.05...|
# | 40|[0.0, 0.0, 0.9947...|
# | 50|[0.0, 0.0, 0.2936...|
# +---+--------------------+
# only showing top 5 rows
#
# +---+--------------------+
# | id|            features|
# +---+--------------------+
# | 20|[0.43706286, 0.0,...|
# | 70|[0.65708596, 0.40...|
# | 80|[0.0, 0.0, 0.0, 0...|
# |100|[0.0, 0.0, 0.0, 0...|
# |110|[0.33686087, 0.10...|
# +---+--------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import lit, current_timestamp, unix_timestamp
ver = final_model.uid
ts = unix_timestamp(current_timestamp())
movie_vectors = final_model.itemFactors.select(col("id").alias("movieId"),
                                               col("features").alias(
                                                   "model_factor"),
                                               lit(ver).alias("model_version"),
                                               ts.alias("model_timestamp"))
movie_vectors.show(5)
user_vectors = final_model.userFactors.select(col("id").alias("userId"),
                                              col("features").alias(
                                                  "model_factor"),
                                              lit(ver).alias("model_version"),
                                              ts.alias("model_timestamp"))
user_vectors.show(5)
# Out:
# +-------+--------------------+----------------+---------------+
# |movieId|        model_factor|   model_version|model_timestamp|
# +-------+--------------------+----------------+---------------+
# |     20|[0.43706286, 0.0,...|ALS_53272c9f13ec|     1734864067|
# |     70|[0.65708596, 0.40...|ALS_53272c9f13ec|     1734864067|
# |     80|[0.0, 0.0, 0.0, 0...|ALS_53272c9f13ec|     1734864067|
# |    100|[0.0, 0.0, 0.0, 0...|ALS_53272c9f13ec|     1734864067|
# |    110|[0.33686087, 0.10...|ALS_53272c9f13ec|     1734864067|
# +-------+--------------------+----------------+---------------+
# only showing top 5 rows
#
# +------+--------------------+----------------+---------------+
# |userId|        model_factor|   model_version|model_timestamp|
# +------+--------------------+----------------+---------------+
# |    10|[0.0, 0.0, 0.3113...|ALS_53272c9f13ec|     1734864067|
# |    20|[0.6109069, 0.0, ...|ALS_53272c9f13ec|     1734864067|
# |    30|[0.28762525, 0.05...|ALS_53272c9f13ec|     1734864067|
# |    40|[0.0, 0.0, 0.9947...|ALS_53272c9f13ec|     1734864067|
# |    50|[0.0, 0.0, 0.2936...|ALS_53272c9f13ec|     1734864067|
# +------+--------------------+----------------+---------------+
# only showing top 5 rows

# %%
movie_vectors.write.format("es") \
    .option("es.mapping.id", "movieId") \
    .option("es.write.operation", "update") \
    .save("movies", mode="append")

# %%
user_vectors.write.format("es") \
    .option("es.mapping.id", "userId") \
    .save("users")

# %%
es.indices.refresh(index="movies")
es.indices.refresh(index="users")
# Out:
# ObjectApiResponse({'_shards': {'total': 2, 'successful': 1, 'failed': 0}})

# %%
def vector_query(query_vec, vector_field, q="*", cosine=False):
    if cosine:
        score_fn = "doc['{v}'].size() == 0 ? 0 : cosineSimilarity(params.vector, '{v}') + 1.0"
    else:
        score_fn = "doc['{v}'].size() == 0 ? 0 : sigmoid(1, Math.E, -dotProduct(params.vector, '{v}'))"

    score_fn = score_fn.format(v=vector_field, fn=score_fn)

    return {
        "query": {
            "script_score": {
                "query": {
                    "query_string": {
                        "query": q
                    }
                },
                "script": {
                    "source": score_fn,
                    "params": {
                        "vector": query_vec
                    }
                }
            }
        }
    }

# %%
def compute_global_params(index="movies"):
    body = {
        "size": 0,
        "aggs": {
            "avg_vote": {"avg": {"field": "vote_average"}},
            "min_votes": {"percentiles": {"field": "vote_count", "percents": [65]}},
            "max_popularity": {"max": {"field": "popularity"}}
        }
    }
    results = es.search(index=index, body=body)
    C = results['aggregations']['avg_vote']['value']
    m = results['aggregations']['min_votes']['values']['65.0']
    P_max = results['aggregations']['max_popularity']['value']
    return C, m, P_max


C, m, P_max = compute_global_params()
lambda_popularity = 0.5

# %%
print(C, m, P_max)
# Out:
# 6.362177934375689 210.1841299320521 547.488298

# %%
def calculate_weighted_rating(v, R, P, C, m, P_max, lambda_popularity=0.5):

    try:
        P = float(P)
    except (TypeError, ValueError):
        print("error p")
        P = 0

    if v > 0:
        wr = ((v / (v + m)) * R) + ((m / (v + m)) * C) + \
            lambda_popularity * (P / P_max if P_max else 0)
    else:
        wr = lambda_popularity * (P / P_max if P_max else 0)
    return wr

# %%
def process_recommendations(hits, C, m, P_max, lambda_popularity=0.5):

    recommendations = []
    for hit in hits:
        rec = hit['_source']
        v = rec.get('vote_count', 0)
        R = rec.get('vote_average', 0)
        P = rec.get('popularity', 0)
        print(v, R, P)
        wr = calculate_weighted_rating(v, R, P, C, m, P_max, lambda_popularity)
        rec['weighted_rating'] = wr
        rec['original_score'] = hit['_score']
        recommendations.append(rec)
    recommendations.sort(key=lambda x: x['weighted_rating'], reverse=True)
    return recommendations

# %%
def get_similar(the_id, q="*", num=10, index="movies", vector_field='model_factor', cosine=False):
    response = es.get(index=index, id=the_id)
    src = response['_source']
    if vector_field in src:
        query_vec = src[vector_field]
        q = vector_query(query_vec, vector_field, q=q, cosine=cosine)
        results = es.search(index=index, body=q)
        hits = results['hits']['hits']
        recommendations = process_recommendations(
            hits, C, m, P_max, lambda_popularity)
        return src, recommendations[:num+1]

# %%
get_similar(2019)
# Out:
# 237 6.1 7.834351
# 1210 7.0 12.715571
# 340 6.5 15.783615
# 1754 5.2 11.902354
# 101 6.1 7.464981
# 320 6.3 9.430812
# 722 6.9 15.831374
# 521 7.7 14.003467
# 369 6.3 13.246795
# 787 6.7 10.529576
# ({'movieId': 2019,
#   'genres': ['Action', 'Adventure', 'Crime', 'Thriller'],
#   'id': 2019,
#   'overview': "When a woman's father goes missing, she enlist a local to aid in her search.  The pair soon discover that her father has died at the hands of a wealthy sportsman who hunts homeless men as a form of recreation.",
#   'popularity': '7.834351',
#   'release_date': 745779600000,
#   'tagline': "Don't hunt what you can't kill.",
#   'title': 'Hard Target',
#   'vote_average': 6.1,
#   'vote_count': 237,
#   'year': 1993,
#   'cast': ['Jean-Claude Van Damme', 'Arnold Vosloo', 'Lance Henriksen'],
#   'crew': [{'name': 'John Woo', 'job': 'Director'},
#    {'name': 'Chuck Pfarrer', 'job': 'Screenplay'},
#    {'name': 'Sean Daniel', 'job': 'Producer'},
#    {'name': 'James Jacks', 'job': 'Producer'},
#    {'name': 'Russell Carpenter', 'job': 'Director of Photography'},
#    {'name': 'Bob Murawski', 'job': 'Editor'},
#    {'name': 'Phil Dagort', 'job': 'Production Design'},
#    {'name': 'Philip Messina', 'job': 'Art Direction'},
#    {'name': 'Michele Poulik', 'job': 'Set Designer'},
#    {'name': 'Karyn Wagner', 'job': 'Costume Design'},
#    {'name': 'Steven Scaffidi', 'job': 'Camera Operator'},
#    {'name': 'Valerie McCaffrey', 'job': 'Casting'},
#    {'name': 'Nancy Nayor', 'job': 'Casting'},
#    {'name': 'Donna Spahn', 'job': 'Hairstylist'},
#    {'name': 'Anne Hieronymus', 'job': 'Makeup Artist'},
#    {'name': 'Marisa Aboitiz', 'job': 'Costume Supervisor'},
#    {'name': 'Faith Conroy', 'job': 'Script Supervisor'},
#    {'name': 'Monroe Kelly', 'job': 'Assistant Art Director'},
#    {'name': 'Steven B. Melton', 'job': 'Property Master'},
#    {'name': 'Dave Kelsey', 'job': 'Scenic Artist'},
#    {'name': 'Cliff Latimer', 'job': 'ADR & Dubbing'},
#    {'name': 'Kevin Bartnof', 'job': 'Foley'},
#    {'name': 'Ellen Heuer', 'job': 'Foley'},
#    {'name': 'David A. Whittaker', 'job': 'Dialogue Editor'},
#    {'name': 'Curt Schulkey', 'job': 'Dialogue Editor'},
#    {'name': 'James Bolt', 'job': 'Sound Re-Recording Mixer'},
#    {'name': 'Michael C. Casper', 'job': 'Sound Re-Recording Mixer'},
#    {'name': 'John Pospisil', 'job': 'Supervising Sound Effects Editor'},
#    {'name': 'George Simpson', 'job': 'Supervising Sound Editor'},
#    {'name': 'John Dunn', 'job': 'Supervising Sound Editor'},
#    {'name': 'Dale L. Martin', 'job': 'Special Effects Coordinator'},
#    {'name': 'William H. Burton Jr.', 'job': 'Stunt Coordinator'},
#    {'name': 'Billy Bragg', 'job': 'Second Unit Cinematographer'},
#    {'name': 'Philip Lee', 'job': 'Camera Operator'},
#    {'name': 'Randy Walsh', 'job': 'Camera Operator'},
#    {'name': 'Frank M. Holgate', 'job': 'Helicopter Camera'},
#    {'name': 'Randy Nolen', 'job': 'Steadicam Operator'},
#    {'name': 'Jeff Mart', 'job': 'Steadicam Operator'},
#    {'name': 'Dick Bernstein', 'job': 'Music Editor'},
#    {'name': 'Patricia Serafina Madiedo', 'job': 'Production Supervisor'},
#    {'name': 'Graeme Revell', 'job': 'Original Music Composer'},
#    {'name': 'Tim Simonec', 'job': 'Original Music Composer'},
#    {'name': 'Sam Raimi', 'job': 'Executive Producer'}],
#   'director': ['John Woo', 'John Woo', 'John Woo'],
#   'keywords': ['drifter',
#    'humanprey',
#    'huntinghumanb',
#    'mercenari',
#    'money',
#    'neworlean',
#    'sailor',
#    'union'],
#   'tmdbId': 2019,
#   'description': "Don't hunt what you can't kill. When a woman's father goes missing, she enlist a local to aid in her search.  The pair soon discover that her father has died at the hands of a wealthy sportsman who hunts homeless men as a form of recreation.",
#   'meta_factor': [-0.028101379051804543,
#    -0.00800325721502304,
#    -0.019266966730356216,
#    0.01647479645907879,
#    0.04725468158721924,
#    0.04344312101602554,
#    0.0816272497177124,
#    -0.03446100652217865,
#    -0.045378364622592926,
#    0.018393244594335556,
#    0.050194524228572845,
#    -0.061678823083639145,
#    0.007546842098236084,
#    0.019059043377637863,
#    0.016104958951473236,
#    0.02066757157444954,
#    0.012193371541798115,
#    0.03712965548038483,
#    0.029272250831127167,
#    0.029241612181067467,
#    -0.06440825015306473,
#    0.0062347580678761005,
#    -0.013260066509246826,
#    -0.007780530955642462,
#    -0.04758448526263237,
#    0.0029107145965099335,
#    0.004758755676448345,
#    0.014990827068686485,
#    -0.023611053824424744,
#    -0.02927238866686821,
#    0.01582825928926468,
#    0.049633994698524475,
#    0.01573939621448517,
#    0.057491712272167206,
#    0.009587367996573448,
#    -0.028534594923257828,
#    0.01122436486184597,
#    0.00583229772746563,
#    -0.002963273786008358,
#    0.03511221706867218,
#    -0.026853792369365692,
#    -0.01584150269627571,
#    0.015483925119042397,
#    -0.00821815524250269,
#    -0.036700911819934845,
#    -0.04387759417295456,
#    -0.0474015548825264,
#    0.003169111907482147,
#    0.06021849066019058,
#    0.04521452635526657,
#    -0.04456719756126404,
#    -0.07367786020040512,
#    -0.029981646686792374,
#    0.01801552250981331,
#    -0.00471203587949276,
#    -0.0791553258895874,
#    -0.02511647343635559,
#    0.03895355761051178,
#    0.015123382210731506,
#    -0.08159352838993073,
#    0.012586016207933426,
#    -5.3989700973033905e-05,
#    -0.030484791845083237,
#     {'name': 'Stanley Kubrick', 'job': 'Producer'},
#     {'name': 'Leonard Rosenman', 'job': 'Original Music Composer'},
#     {'name': 'John Alcott', 'job': 'Director of Photography'},
#     {'name': 'Bernard Williams', 'job': 'Producer'},
#     {'name': 'Jan Harlan', 'job': 'Executive Producer'},
#     {'name': 'Roy Walker', 'job': 'Art Direction'},
#     {'name': 'Milena Canonero', 'job': 'Costume Design'},
#     {'name': 'Tony Lawson', 'job': 'Editor'},
#     {'name': 'Rodney Holland', 'job': 'Sound Designer'},
#     {'name': 'Alan Boyle', 'job': 'Makeup Artist'},
#     {'name': 'William Makepeace Thackeray', 'job': 'Novel'},
#     {'name': 'Ulla-Britt Söderlund', 'job': 'Costume Design'}],
#    'director': ['Stanley Kubrick', 'Stanley Kubrick', 'Stanley Kubrick'],
#    'keywords': ['britisharmi',
#     'britishsoldi',
#     'debt',
#     'epic',
#     'fenc',
#     'ireland',
#     'nobil',
#     'palac',
#     'prussia',
#     'sevenyearswar'],
#    'tmdbId': 3175,
#    'description': 'At long last Redmond Barry became a gentleman - and that was his tragedy. In the Eighteenth Century, in a small village in Ireland, Redmond Barry is a young farm boy in love with his cousin Nora Brady. When Nora engages to the British Captain John Quin, Barry challenges him for a duel of pistols. He wins and escapes to Dublin, but is robbed on the road. Without any other alternative, Barry joins the British Army to fight in the Seven Years War.',
#    'meta_factor': [-0.01668446883559227,
#     -0.0069973585195839405,
#     -0.054212260991334915,
#     -0.021412961184978485,
#     0.011229772120714188,
#     0.11111460626125336,
#     -0.015315028838813305,
#     0.01325854193419218,
#     -0.02015717700123787,
#     0.004687352105975151,
#     -0.018182791769504547,
#     -0.004330530762672424,
#     -0.04994433373212814,
#     -0.017140723764896393,
#     -0.04157531261444092,
#     0.008375262841582298,
#     -0.04793204739689827,
#     0.0006932485848665237,
#     -0.012928379699587822,
#     0.005565043538808823,
#     -0.041598111391067505,
#     -0.013723772950470448,
#     -0.005181930959224701,
#     0.005210798233747482,
#     -0.024498771876096725,
#     0.031024232506752014,
#     0.01885346882045269,
#     -0.0028679161332547665,
#     -0.05065392330288887,
#     -0.02897818014025688,
#     0.042682234197854996,
#     0.02928198128938675,
#     0.04958304390311241,
#     0.029768330976366997,
#     0.043406590819358826,
#     -0.028413893654942513,
#     -0.034441471099853516,
#     0.03911836817860603,
#     -0.0008600717410445213,
#     -0.02855193056166172,
#     -0.055902302265167236,
#     -0.0768967866897583,
#     0.006332739721983671,
#     0.004465716890990734,
#     0.041394639760255814,
#     -0.01626415364444256,
#     0.0035246219485998154,
#     -0.02635536715388298,
#     0.037110261619091034,
#     0.037381529808044434,
#     -0.017037415876984596,
#     0.012625452131032944,
#     -0.027760237455368042,
#     0.020464811474084854,
#     0.1096520870923996,
#     -0.05321146547794342,
#     0.01776565983891487,
#     0.014014325104653835,
#     -0.0156985092908144,
#     -0.010097691789269447,
#     -0.039055176079273224,
#     -0.0028787199407815933,
#     -0.04335832595825195,
#     -0.06739646196365356,
#     -0.011651493608951569,
#     -0.002441924996674061,
#     -0.004640864674001932,
#     0.02474028430879116,
#     0.045865342020988464,
#     -0.05328890681266785,
#     0.062366191297769547,
#     -0.06924204528331757,
#     0.029681753367185593,
#     -3.656027658394123e-08,
#     0.006202099844813347,
#     0.027175618335604668,
#     -0.039905138313770294,
#     0.0006384889129549265,
#     0.005152872763574123,
#     0.004016650840640068,
#     0.014018849469721317,
#     0.019768688827753067,
#     -0.012045854702591896,
#     0.03661599010229111,
#     0.006002157926559448,
#     0.019794650375843048,
#     0.02807992696762085,
#     -0.02951180562376976,
#     0.0018838010728359222,
#     -0.02966850809752941,
#     0.018950939178466797,
#     -0.08026283979415894,
#     -0.007968680933117867,
#     0.01180257834494114,
#     0.0544893816113472,
#     -0.03008049912750721,
#     0.019472705200314522,
#     -0.04075149819254875,
#     -0.028801022097468376,
#     0.0031463531777262688,
#     0.045564278960227966,
#     -0.026206158101558685,
#     0.00041244359454140067,
#     0.03789973258972168,
#     0.04445825517177582,
#     0.03310170769691467,
#     -0.033653877675533295,
#     -0.031081221997737885,
#     0.00784086249768734,
#     -0.01581558957695961,
#     0.04011569172143936,
#     -0.0018838811665773392,
#     -0.06238514930009842,
#     0.01623888872563839,
#     -0.07251019030809402,
#     0.03188184276223183,
#     -0.01869918406009674,
#     -0.018616044893860817,
#     0.034580010920763016,
#     -0.006954029202461243,
#     0.008505728095769882,
#     0.0237905103713274,
#     0.019007468596100807,
#     -0.02073707990348339,
#     0.012867542915046215,
#     0.016394613310694695,
#     0.01652894727885723,
#     0.03581111133098602,
#     0.0196030605584383,
#     0.0068493494763970375,
#     -0.0042539360001683235,
#     0.028882531449198723,
#     -0.01602037623524666,
#     -0.042088575661182404,
#     0.06610476970672607,
#     -0.04183074086904526,
#     -0.006170833948999643,
#     0.015050140209496021],
#    'model_timestamp': 1734864075,
#    'model_version': 'ALS_53272c9f13ec',
#    'model_factor': [0.25260624,
#     0.2137725,
#     0.09513284,
#     0.051613193,
#     0.022359801,
#     0.18537328,
#     0.0,
#     0.36018196,
#     0.21313533,
#     0.18485703,
#     0.16427018,
#     0.1379526,
#     0.0,
#     0.8635767,
#     0.06806962,
#     0.2039473,
#     0.6537934,
#     0.0,
#     0.59774953,
#     0.06823322],
#    'weighted_rating': 7.328222265912317,
#    'original_score': 0.8532501},
#   {'movieId': 1272,
#    'genres': ['Science Fiction', 'Thriller'],
#    'id': 1272,
#    'overview': 'Fifty years into the future, the sun is dying, and Earth is threatened by arctic temperatures. A team of astronauts is sent to revive the Sun — but the mission fails. Seven years later, a new team is sent to finish the mission as mankind’s last hope.',
#    'popularity': '12.715571',
#    'release_date': 1175706000000,
#    'tagline': 'If the sun dies, so do we.',
#    'title': 'Sunshine',
#    'vote_average': 7.0,
#    'vote_count': 1210,
#    'year': 2007,
#    'cast': ['Cillian Murphy', 'Rose Byrne', 'Chris Evans'],
#    'crew': [{'name': 'Chris Gill', 'job': 'Editor'},
#     {'name': 'John Murphy', 'job': 'Music'},
#     {'name': 'Danny Boyle', 'job': 'Director'},
#     {'name': 'Andrew Macdonald', 'job': 'Producer'},
#     {'name': 'Alex Garland', 'job': 'Screenplay'},
#     {'name': 'Mark Tildesley', 'job': 'Production Design'},
#     {'name': 'Gail Stevens', 'job': 'Casting'},
#     {'name': 'Donna Isaacson', 'job': 'Casting'},
#     {'name': 'Alwin H. Kuchler', 'job': 'Director of Photography'},
#     {'name': 'Michelle Day', 'job': 'Set Decoration'},
#     {'name': 'Suttirat Anne Larlarb', 'job': 'Costume Design'},
#     {'name': 'Michael Mooney', 'job': 'Costume Supervisor'},
#     {'name': 'David Warren', 'job': 'Supervising Art Director'}],
#    'director': ['Danny Boyle', 'Danny Boyle', 'Danny Boyle'],
#    'keywords': ['bomb',
#     'earth',
#     'expir',
#     'savingtheworld',
#     'solarenergi',
#     'spacemarin',
#     'spacemiss',
#     'sun',
#     'sunlight'],
#    'tmdbId': 1272,
#    'description': 'If the sun dies, so do we. Fifty years into the future, the sun is dying, and Earth is threatened by arctic temperatures. A team of astronauts is sent to revive the Sun — but the mission fails. Seven years later, a new team is sent to finish the mission as mankind’s last hope.',
#    'meta_factor': [-0.035498108714818954,
#     0.03905028477311134,
#     0.022566329687833786,
#     0.0445542111992836,
#     0.03932604938745499,
#     0.010274285450577736,
#     0.06771154701709747,
#     -0.04848112910985947,
#     0.029617616906762123,
#     0.00070948526263237,
#     0.039851993322372437,
#     -0.05348678305745125,
#     -0.008469237014651299,
#     0.062182679772377014,
#     0.04071427509188652,
#     0.0194191075861454,
#     -0.010386595502495766,
#     -0.017575949430465698,
#     -0.053381361067295074,
#     -0.04018034040927887,
#     -0.05153272673487663,
#     0.03473600000143051,
#     -0.031795039772987366,
#     0.026366760954260826,
#     -0.014884009957313538,
#     0.0642782524228096,
#     -0.014327633194625378,
#     0.006518776994198561,
#     -0.06336104869842529,
#     -0.000787636439781636,
#     0.014393359422683716,
#     0.044045932590961456,
#     -0.022474095225334167,
#     -0.020869068801403046,
#     0.04558379203081131,
#     0.05928631126880646,
#     -0.019096147269010544,
#     -0.10196110606193542,
#     -0.029883960261940956,
#     -0.011821463704109192,
#     -0.06616263836622238,
#     -0.11172926425933838,
#     -0.0011434187181293964,
#     0.030487168580293655,
#     -0.02913932502269745,
#     -0.026064779609441757,
#     -0.020335007458925247,
#     -0.06509684026241302,
#     0.06990759074687958,
#     0.023556649684906006,
#     -0.029563764110207558,
#     -0.04987315833568573,
#     -0.0471026748418808,
#     0.006791976280510426,
#     0.026068568229675293,
#     -0.0011480525135993958,
#     -0.010371394455432892,
#     0.01409985776990652,
#     0.005321810953319073,
#     -0.09468939900398254,
#     0.0027425987645983696,
#     -0.053663674741983414,
#     -0.041520047932863235,
#     -0.009901929646730423,
#     0.08751709014177322,
#     0.020962513983249664,
#     -0.02801581472158432,
#     -0.04844050109386444,
#     0.00677518080919981,
#     -0.06096584349870682,
#     -0.05051972717046738,
#     -0.005998419597744942,
#     -0.06658654659986496,
#     -0.04046470299363136,
#     -0.02879694104194641,
#     0.04342865198850632,
#     0.028951307758688927,
#     -0.025241997092962265,
#     0.040169693529605865,
#     -0.043633997440338135,
#     0.06988825649023056,
#     -0.07093408703804016,
#     0.058327510952949524,
#     0.004181317985057831,
#     0.04814595729112625,
#     -0.015829093754291534,
#     0.019125167280435562,
#     0.09419694542884827,
#     -0.016880137845873833,
#     -0.05681341513991356,
#     -0.025776181370019913,
#     0.03191116452217102,
#     0.028560031205415726,
#     -0.005363872274756432,
#     -0.011589305475354195,
#     -0.01540230680257082,
#     -0.036829862743616104,
#     0.06132787466049194,
#     -0.049396052956581116,
#     0.011481832712888718,
#     0.02964586764574051,
#     0.029040323570370674,
#     0.038763124495744705,
#     0.04344257339835167,
#     -1.2307427823543549e-05,
#     -0.010071909986436367,
#     -0.013223170302808285,
#     -0.00939195230603218,
#     -0.04923573136329651,
#     -0.04419416934251785,
#     -0.004887092858552933,
#     0.03543556481599808,
#     0.03425830230116844,
#     -0.025275666266679764,
#     0.019042618572711945,
#     -0.04905165731906891,
#     0.0749858021736145,
#     0.0010712668299674988,
#     0.026734691113233566,
#     -0.01945502497255802,
#     -0.027165519073605537,
#     0.03603890910744667,
#     -0.03641510382294655,
#     -0.023733634501695633,
#     0.0016017649322748184,
#     0.03208443522453308,
#     -0.015389648266136646,
#     -0.026029622182250023,
#     0.032995570451021194,
#     -0.003556320443749428,
#     0.03064149245619774,
#     -0.03210128843784332,
#     0.04470702260732651,
#     -0.04532632976770401,
#     -0.0016286533791571856,
#     0.027128931134939194,
#     -0.018803071230649948,
#     -0.06751744449138641,
#     -0.01766914501786232],
#    'model_timestamp': 1734864075,
#    'model_version': 'ALS_53272c9f13ec',
#    'model_factor': [0.28598863,
#     0.024698908,
#     0.0,
#     0.18592355,
#     0.05483461,
#     0.14640091,
#     0.45815393,
#     0.0,
#     0.15990783,
#     0.29729283,
#     0.058247957,
#     0.1563243,
#     0.025637966,
#     0.62047476,
#     0.1884078,
#     0.2764575,
#     0.6478205,
#     0.0,
#     0.774801,
#     0.2125058],
#    'weighted_rating': 6.917216377910959,
#    'original_score': 0.8675319},
#   {'movieId': 926,
#    'genres': ['Comedy', 'Family', 'Science Fiction'],
#    'id': 926,
#    'overview': "The stars of a 1970s sci-fi show - now scraping a living through re-runs and sci-fi conventions - are beamed aboard an alien spacecraft. Believing the cast's heroic on-screen dramas are historical documents of real-life adventures, the band of aliens turn to the ailing celebrities for help in their quest to overcome the oppressive regime in their solar system.",
#    'popularity': '15.831374',
#    'release_date': 945882000000,
#    'tagline': 'A comedy of Galactic Proportions.',
#    'title': 'Galaxy Quest',
#    'vote_average': 6.9,
#    'vote_count': 722,
#    'year': 1999,
#    'cast': ['Tim Allen', 'Sigourney Weaver', 'Alan Rickman'],
#    'crew': [{'name': 'Dean Parisot', 'job': 'Director'},
#     {'name': 'David Howard', 'job': 'Screenplay'},
#     {'name': 'Mark Johnson', 'job': 'Producer'},
#     {'name': 'Charles Newirth', 'job': 'Producer'},
#     {'name': 'David Newman', 'job': 'Original Music Composer'},
#     {'name': 'Jerzy Zielinski', 'job': 'Director of Photography'},
#     {'name': 'Don Zimmerman', 'job': 'Editor'},
#     {'name': 'Debra Zane', 'job': 'Casting'},
#     {'name': 'Linda DeScenna', 'job': 'Production Design'},
#     {'name': 'James Nedza', 'job': 'Art Direction'},
#     {'name': 'Ric McElvin', 'job': 'Set Decoration'},
#     {'name': 'Albert Wolsky', 'job': 'Costume Design'},
#     {'name': 'Charles Newirth', 'job': 'Unit Production Manager'},
#     {'name': 'J.J. George', 'job': 'Music Editor'},
#     {'name': 'Keith Marbory', 'job': 'Special Effects Coordinator'},
#     {'name': 'William N. Greene III', 'job': 'Special Effects'},
#     {'name': 'Mat Beck', 'job': 'Visual Effects Supervisor'},
#     {'name': 'David S. Dranitzke', 'job': 'Visual Effects'},
#     {'name': 'Andy Armstrong', 'job': 'Stunt Coordinator'},
#     {'name': 'James Armstrong', 'job': 'Utility Stunts'},
#     {'name': 'Robert Gordon', 'job': 'Screenplay'},
#     {'name': 'Robert Q. Mathews', 'job': 'Costume Supervisor'},
#     {'name': 'David Newman', 'job': 'Orchestrator'},
#     {'name': 'Jeff Carson', 'job': 'Music Supervisor'},
#     {'name': 'Ashley Fardys', 'job': 'Art Department Coordinator'},
#     {'name': 'Terri Taylor', 'job': 'Casting Associate'},
#     {'name': 'George L. Little', 'job': 'Assistant Costume Designer'},
#     {'name': 'Joy Zapata', 'job': 'Hair Department Head'},
#     {'name': "Alan D'Angerio", 'job': 'Hairstylist'},
#     {'name': 'Ve Neill', 'job': 'Makeup Department Head'},
#     {'name': 'Bill Corso', 'job': 'Makeup Artist'},
#     {'name': "Hallie D'Amore", 'job': 'Makeup Artist'},
#     {'name': 'Hugh Waddell', 'job': 'ADR & Dubbing'},
#     {'name': 'Jessica Gallavan', 'job': 'ADR & Dubbing'},
#     {'name': 'Jayme S. Parker', 'job': 'ADR & Dubbing'},
#     {'name': 'Claire Graybill', 'job': 'Dialogue Editor'},
#     {'name': 'Ewa Sztompke', 'job': 'Dialogue Editor'},
#     {'name': 'Marnie Moore', 'job': 'Foley'},
#     {'name': "Margie O'Malley", 'job': 'Foley'},
#     {'name': 'Richard Beggs', 'job': 'Sound Designer'},
#     {'name': 'J.R. Grubbs', 'job': 'Sound Effects Editor'},
#     {'name': 'Tim Nielsen', 'job': 'Sound Effects Editor'},
#     {'name': 'Karen G. Wilson', 'job': 'Sound Effects Editor'},
#     {'name': 'Lora Hirschberg', 'job': 'Sound Re-Recording Mixer'},
#     {'name': 'Tom Johnson', 'job': 'Sound Re-Recording Mixer'},
#     {'name': 'Tim Holland', 'job': 'Supervising Sound Editor'}],
#    'director': ['Dean Parisot', 'Dean Parisot', 'Dean Parisot'],
#    'keywords': ['fictionaltvshow', 'spacebattl', 'spaceship', 'spoof'],
#    'tmdbId': 926,
#    'description': "A comedy of Galactic Proportions. The stars of a 1970s sci-fi show - now scraping a living through re-runs and sci-fi conventions - are beamed aboard an alien spacecraft. Believing the cast's heroic on-screen dramas are historical documents of real-life adventures, the band of aliens turn to the ailing celebrities for help in their quest to overcome the oppressive regime in their solar system.",
#    'meta_factor': [-0.06158807873725891,
#     -0.03309395909309387,
#     -0.026572685688734055,
#     -0.0007024416700005531,
#     -0.04015123099088669,
#     0.0005348734557628632,
#     -0.017040401697158813,
#     0.03996845334768295,
#     -0.022900599986314774,
#     0.057419441640377045,
#     0.033846862614154816,
#     -0.04986559599637985,
#     0.06640474498271942,
#     -0.039208363741636276,
#     -0.057579439133405685,
#     -0.036711499094963074,
#     -0.007814687676727772,
#     -0.04878732189536095,
#     -0.014475539326667786,
#     -0.03941038250923157,
#     -0.00043190643191337585,
#     -0.013942432589828968,
#     -0.026989329606294632,
#     0.0009054131805896759,
#     -0.02264903485774994,
#     -0.050050608813762665,
#     0.039913032203912735,
#     -0.03681245073676109,
#     -0.04608006030321121,
#     0.03222038969397545,
#     0.001208202913403511,
#     0.011099277064204216,
#     -0.032545868307352066,
#     0.0537717342376709,
#     0.037224918603897095,
#     -0.03839913383126259,
#     0.05753855034708977,
#     0.00750370416790247,
#     -0.024808524176478386,
#     0.04832349717617035,
#     0.005067842081189156,
#     -0.02445322647690773,
#     -0.07670702785253525,
#     0.016940051689743996,
#     0.058396391570568085,
#     -0.04147832840681076,
#     -0.0009959712624549866,
#     -0.016058407723903656,
#     0.028157025575637817,
#     -0.04784421995282173,
#     0.031267449259757996,
#     0.06287255883216858,
#     -0.04379966855049133,
#     0.05512299761176109,
#     0.11128800362348557,
#     -0.005293955095112324,
#     0.012712966650724411,
#     -0.054497234523296356,
#     -0.05486177280545235,
#     0.03163134306669235,
#     -0.008779270574450493,
#     -0.013674840331077576,
#     0.008716252632439137,
#     0.01211693324148655,
#     -0.009003846906125546,
#     0.03514914959669113,
#     -0.008522075600922108,
#     0.07227560877799988,
#     0.03611837327480316,
#     0.022608958184719086,
#     0.01665075495839119,
#     0.040053725242614746,
#     -0.029293928295373917,
# ...
#     0.026655737310647964,
#     0.02095094695687294,
#     0.015927208587527275,
#     -0.01341073215007782,
#     0.011259754188358784,
#     0.10190935432910919,
#     -0.0468660369515419,
#     0.006600484251976013,
#     0.008222870528697968],
#    'model_timestamp': 1734864075,
#    'model_version': 'ALS_53272c9f13ec',
#    'model_factor': [0.1691732,
#     0.19003136,
#     0.09192515,
#     0.07773016,
#     0.0068260888,
#     0.20052442,
#     0.36504298,
#     0.03791715,
#     0.42742792,
#     0.19151013,
#     0.16576876,
#     0.13976024,
#     0.034124788,
#     0.5877325,
#     0.26426,
#     0.24857277,
#     0.8328947,
#     0.19456755,
#     0.5156795,
#     0.16398318],
#    'weighted_rating': 6.230382889774618,
#    'original_score': 0.88320726},
#   {'movieId': 1250,
#    'genres': ['Thriller', 'Action', 'Fantasy', 'Horror'],
#    'id': 1250,
#    'overview': "In order to save his dying father, young stunt cyclist, Johnny Blaze sells his soul to Mephistopheles and sadly parts from the pure-hearted, Roxanne Simpson, the love of his life. Years later, Johnny's path crosses again with Roxanne, now a go-getting reporter, and also with Mephistopheles, who offers to release Johnny's soul if Johnny becomes the fabled, fiery 'Ghost Rider'.",
#    'popularity': '11.902354',
#    'release_date': 1171558800000,
#    'tagline': 'Hell Is About To Be Unleashed',
#    'title': 'Ghost Rider',
#    'vote_average': 5.2,
#    'vote_count': 1754,
#    'year': 2007,
#    'cast': ['Nicolas Cage', 'Eva Mendes', 'Wes Bentley'],
#    'crew': [{'name': 'Jeanne McCarthy', 'job': 'Casting'},
#     {'name': 'Richard Francis-Bruce', 'job': 'Editor'},
#     {'name': 'Michael De Luca', 'job': 'Producer'},
#     {'name': 'Avi Arad', 'job': 'Producer'},
#     {'name': 'Christopher Young', 'job': 'Original Music Composer'},
#     {'name': 'Peter Russell', 'job': 'Art Direction'},
#     {'name': 'Lisa Brennan', 'job': 'Property Master'},
#     {'name': 'Dane A. Davis', 'job': 'Sound Designer'},
#     {'name': 'Dane A. Davis', 'job': 'Supervising Sound Editor'},
#     {'name': 'Juel Bestrop', 'job': 'Casting'},
#     {'name': 'Christine King', 'job': 'Casting'},
#     {'name': 'Gary Foster', 'job': 'Producer'},
#     {'name': 'Lizzy Gardiner', 'job': 'Costume Design'},
#     {'name': 'Kirk M. Petruccelli', 'job': 'Production Design'},
#     {'name': 'Mark Steven Johnson', 'job': 'Screenplay'},
#     {'name': 'Mark Steven Johnson', 'job': 'Director'},
#     {'name': 'Steven Paul', 'job': 'Producer'},
#     {'name': 'Ilona Herman', 'job': 'Makeup Artist'},
#     {'name': 'Russell Boyd', 'job': 'Director of Photography'},
#     {'name': 'Richard Hobbs', 'job': 'Supervising Art Director'},
#     {'name': 'Suza Maybury', 'job': 'Set Decoration'},
#     {'name': 'Ryan Nicholson', 'job': 'Makeup Effects'},
#     {'name': 'John Dunn', 'job': 'Sound Effects Editor'},
#     {'name': 'David A. Whittaker', 'job': 'Sound Effects Editor'},
#     {'name': 'Lesley Vanderwalt', 'job': 'Hairstylist'},
#     {'name': 'Matt Corrigan', 'job': 'Makeup Effects'},
#     {'name': 'Gary A. Hecker', 'job': 'Foley'},
#     {'name': 'Peter Collias', 'job': 'Scenic Artist'},
#     {'name': 'Margot Ready', 'job': 'Assistant Art Director'},
#     {'name': 'Donald Flick', 'job': 'Sound Effects Editor'},
#     {'name': 'Eric Lindemann', 'job': 'Sound Effects Editor'},
#     {'name': 'Michael J. Broomberg', 'job': 'Foley'},
#     {'name': 'Tony Lees', 'job': 'Sculptor'},
#     {'name': 'Greg Hedgepath', 'job': 'Sound Effects Editor'},
#     {'name': 'William R. Dean', 'job': 'Sound Effects Editor'},
#     {'name': 'Greg Orloff', 'job': 'Sound Re-Recording Mixer'},
#     {'name': 'Gary C. Bourgeois', 'job': 'Sound Re-Recording Mixer'},
#     {'name': 'Jennifer Stanfield', 'job': 'Hairstylist'},
#     {'name': 'Kate Birch', 'job': 'Hairstylist'},
#     {'name': 'Stephanie Flack', 'job': 'Dialogue Editor'},
#     {'name': 'Miles Teves', 'job': 'Conceptual Design'},
#     {'name': 'David A. Cohen', 'job': 'Dialogue Editor'},
#     {'name': 'Jenny Hitchcock', 'job': 'Set Designer'},
#     {'name': 'Katherine Brown', 'job': 'Makeup Effects'},
#     {'name': 'Ian Richter', 'job': 'Scenic Artist'},
#     {'name': 'Bobbi Banks', 'job': 'ADR & Dubbing'},
#     {'name': 'Dave Elsey', 'job': 'Makeup Effects'},
#     {'name': 'Ferdinando Merolla', 'job': 'Hairstylist'},
#     {'name': 'Liz Harper', 'job': 'Makeup Artist'},
#     {'name': 'Louise Coulston', 'job': 'Makeup Artist'},
#     {'name': 'Ayma Letang', 'job': 'Makeup Effects'},
#     {'name': 'Jason Ward', 'job': 'Makeup Effects'},
#     {'name': 'Tim Lyall', 'job': 'Art Department Coordinator'},
#     {'name': 'Peta Ross', 'job': 'Construction Coordinator'},
#     {'name': 'Marcus Smith', 'job': 'Construction Coordinator'},
#     {'name': 'Matthew Cotter', 'job': 'Sculptor'},
#     {'name': 'Simon Coke', 'job': 'Sound Effects Editor'},
#     {'name': 'Caroline Kelly', 'job': 'Special Effects Coordinator'}],
#    'director': ['Mark Steven Johnson',
#     'Mark Steven Johnson',
#     'Mark Steven Johnson'],
#    'keywords': ['basedoncom',
#     'demon',
#     "devil'sson",
#     'dyinganddeath',
#     'flame',
#     'ghostworld',
#     'religionandsupernatur',
#     'stunt'],
#    'tmdbId': 1250,
#    'description': "Hell Is About To Be Unleashed In order to save his dying father, young stunt cyclist, Johnny Blaze sells his soul to Mephistopheles and sadly parts from the pure-hearted, Roxanne Simpson, the love of his life. Years later, Johnny's path crosses again with Roxanne, now a go-getting reporter, and also with Mephistopheles, who offers to release Johnny's soul if Johnny becomes the fabled, fiery 'Ghost Rider'.",
#    'meta_factor': [-0.030863642692565918,
#     0.06095500290393829,
#     -0.06306680291891098,
#     -0.00987325794994831,
#     0.0030371779575943947,
#     0.07015120983123779,
#     0.081302709877491,
#     -0.06443287432193756,
#     0.05459520220756531,
#     -0.010253564454615116,
#     0.017012301832437515,
#     -0.032482266426086426,
#     0.03318382427096367,
#     0.03600489720702171,
#     -0.02398909069597721,
#     0.0366944894194603,
#     0.033551208674907684,
#     0.11556798219680786,
#     -0.009111670777201653,
#     0.035337794572114944,
#     -0.016822759062051773,
#     0.03291887789964676,
#     -0.04933486506342888,
#     0.015279468148946762,
#     -0.02611997351050377,
#     0.003479798324406147,
#     -0.006631219759583473,
#     0.002283539855852723,
#     -0.01721450313925743,
#     -0.07301260530948639,
#     0.0003570113331079483,
#     0.0013503606896847486,
#     -0.08582760393619537,
#     -0.03246550261974335,
#     0.0028996234759688377,
#     -0.024157103151082993,
#     -0.03624490648508072,
#     -0.011308867484331131,
#     -0.011792317032814026,
#     -0.03208201751112938,
#     -0.04396360367536545,
#     0.005307573825120926,
#     -0.009853959083557129,
#     -0.02436765469610691,
#     7.472513243556023e-05,
#     -0.08142712712287903,
#     -0.011029839515686035,
#     -0.028599534183740616,
#     0.059852201491594315,
#     0.014342752285301685,
#     0.0014779968187212944,
#     -0.04640518128871918,
#     0.06369784474372864,
#     0.030608002096414566,
#     -0.024085279554128647,
#     -0.06183783337473869,
#     -0.04830358922481537,
#     0.02246963046491146,
#     -0.02628699317574501,
#     -0.05595138669013977,
#     0.013227113522589207,
#     0.02423389069736004,
#     -0.016068467870354652,
#     -0.027380051091313362,
#     0.02586444281041622,
#     -0.014267126098275185,
#     -0.022912174463272095,
#     -0.013787316158413887,
#     0.008332077413797379,
#     0.013346324674785137,
#     0.03457421064376831,
#     0.04485169053077698,
#     -0.02570590376853943,
#     -0.07476980984210968,
#     -3.5414032595326717e-08,
#     -0.032503340393304825,
#     -0.028773561120033264,
#     -0.017436333000659943,
#     -0.025243863463401794,
#     0.00827018916606903,
#     0.023731529712677002,
#     0.056357964873313904,
#     -0.008686469867825508,
#     -0.041884131729602814,
#     0.09743660688400269,
#     0.02792397141456604,
#     0.0060999393463134766,
#     0.05168963596224785,
#     -0.018562372773885727,
#     -0.04014618694782257,
#     -0.03787216544151306,
#     -0.04695650935173035,
#     0.04721614718437195,
#     -0.03680122643709183,
#     -0.03466241434216499,
#     0.010545293800532818,
#     0.02376408502459526,
#     0.09740238636732101,
#     -0.07234400510787964,
#     0.06432832777500153,
#     -0.03610105812549591,
#     -0.024739239364862442,
#     -0.030976518988609314,
#     0.018640145659446716,
#     0.057152159512043,
#     0.02859017252922058,
#     0.06814411282539368,
#     -0.03620295599102974,
#     -0.00722313579171896,
#     -0.08381789922714233,
#     -0.032191287726163864,
#     -0.00025083404034376144,
#     0.08005151897668839,
#     -0.003405303694307804,
#     -0.051053486764431,
#     0.02062380686402321,
#     0.01993558183312416,
#     0.0716637372970581,
#     -0.03074423223733902,
#     -0.015541338361799717,
#     -0.05592895299196243,
#     0.0006763031706213951,
#     -0.10124758630990982,
#     0.030210450291633606,
#     -0.061250150203704834,
#     0.004717936739325523,
#     -0.043070197105407715,
#     0.0009280666708946228,
#     0.06439660489559174,
#     0.07542218267917633,
#     -0.011178366839885712,
#     0.002323355060070753,
#     0.07556216418743134,
#     0.0031509692780673504,
#     -0.01628824882209301,
#     0.05013522878289223,
#     -0.0641845315694809,
#     0.03409741818904877,
#     -0.020010115578770638],
#    'model_timestamp': 1734864075,
#    'model_version': 'ALS_53272c9f13ec',
#    'model_factor': [0.34798235,
#     0.07205738,
#     0.22498222,
#     0.050059415,
#     0.02452172,
#     0.08092954,
#     0.4192506,
#     0.19852802,
#     0.108845204,
#     0.1667514,
#     0.06477189,
#     0.113068394,
#     0.0,
#     0.7446976,
#     0.22421582,
#     0.29685903,
#     0.65589803,
#     0.0,
#     0.48203644,
#     0.27192593],
#    'weighted_rating': 5.335232721203453,
#    'original_score': 0.8568399}])

# %%
def get_user_recs(the_id, q="*", num=10, users="users", movies="movies", vector_field='model_factor'):
    response = es.get(index=users, id=the_id)
    src = response['_source']
    if vector_field in src:
        query_vec = src[vector_field]
        q = vector_query(query_vec, vector_field, q=q, cosine=False)
        results = es.search(index=movies, body=q)
        hits = results['hits']['hits']
        recommendations = process_recommendations(
            hits, C, m, P_max, lambda_popularity)
        return src, recommendations[:num]

# %%
import json
from requests import HTTPError
import requests


def get_poster_url(movie_id):
    try:
        IMAGE_URL = 'https://image.tmdb.org/t/p/w500'
        url = "https://api.themoviedb.org/3/movie/" + \
            str(movie_id) + "?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkNDM4ZjJmOGVmMjk5ZmI4ZTA5MWVlZDEyZWY0YzQyMiIsIm5iZiI6MTY3MDEyNzA0NC43Niwic3ViIjoiNjM4YzFkYzQwZTY0YWYwMGRlYWIyMTQ5Iiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.o2bVzOt4bu9yJCQnB-7TLgyF-_VSS-sLPhQ8YAdz0-U"
        }
        movie_info = requests.get(url, headers=headers)
        movie_info = json.loads(movie_info.text)
        movie_poster_url = IMAGE_URL + movie_info['poster_path']
        return movie_poster_url
    except HTTPError as e:
        if e.response.status_code == 401:
            j = json.loads(e.response.text)
            print(j)

# %%
def get_hybrid_recommendations(user_id, content_id, alpha=0.5, num=10,
                               user_index="users", movie_index="movies",
                               user_vector_field='model_factor', content_vector_field='meta_factor'):

    user_src, user_recs = get_user_recs(
        user_id, users=user_index, movies=movie_index, vector_field=user_vector_field, num=num * 2)
    user_scores = {rec['movieId']: rec['original_score'] for rec in user_recs}
    content_src, content_recs = get_similar(
        content_id, index=movie_index, vector_field=content_vector_field, num=num * 2, cosine=False)
    content_scores = {rec['movieId']: rec['original_score']
                      for rec in content_recs}
    combined_scores = {}
    for movie_id in set(user_scores.keys()).union(content_scores.keys()):
        user_score = user_scores.get(movie_id, 0)
        content_score = content_scores.get(movie_id, 0)
        combined_scores[movie_id] = alpha * \
            user_score + (1 - alpha) * content_score
    ranked_movies = sorted(combined_scores.items(),
                           key=lambda x: x[1], reverse=True)[:num]
    recommendations = []
    for movie_id, score in ranked_movies:
        movie_data = es.get(index=movie_index, id=movie_id)['_source']
        movie_data['score'] = score
        recommendations.append(movie_data)
    return recommendations

# %%
get_hybrid_recommendations(1, 2019)
# Out:
# 894 6.6 11.673366
# 688 5.3 14.007329
# 10 5.1 1.523446
# 2344 7.4 12.477872
# 1743 6.6 14.178281
# 48 6.5 12.130265
# 984 6.6 10.25721
# 384 6.4 7.008512
# 913 5.7 12.093928
# 146 5.6 9.243715
# 237 6.1 7.834351
# 194 6.0 7.481524
# 1240 7.2 10.08937
# 3083 7.7 15.565484
# 57 7.2 3.467871
# 109 5.9 9.337393
# 26 6.2 5.432879
# 7 5.1 1.217249
# 404 7.2 9.070215
# 1231 6.0 9.034929
# [{'movieId': 1371,
#   'genres': ['Drama'],
#   'id': 1371,
#   'overview': 'Now the world champion, Rocky Balboa is living in luxury and only fighting opponents who pose no threat to him in the ring. His lifestyle of wealth and idleness is shaken when a powerful young fighter known as Clubber Lang challenges him to a bout. After taking a pounding from Lang, the humbled champ turns to former bitter rival Apollo Creed to help him regain his form for a rematch with Lang.',
#   'popularity': '11.673366',
#   'release_date': 391366800000,
#   'tagline': 'The greatest challenge.',
#   'title': 'Rocky III',
#   'vote_average': 6.6,
#   'vote_count': 894,
#   'year': 1982,
#   'cast': ['Sylvester Stallone', 'Talia Shire', 'Burt Young'],
#   'crew': [{'name': 'Sylvester Stallone', 'job': 'Director'},
#    {'name': 'Sylvester Stallone', 'job': 'Screenplay'},
#    {'name': 'Robert Chartoff', 'job': 'Producer'},
#    {'name': 'Irwin Winkler', 'job': 'Producer'},
#    {'name': 'Bill Conti', 'job': 'Original Music Composer'},
#    {'name': 'Bill Butler', 'job': 'Director of Photography'},
#    {'name': 'Mark Warner', 'job': 'Editor'},
#    {'name': 'Don Zimmerman', 'job': 'Editor'},
#    {'name': 'Rhonda Young', 'job': 'Casting'},
#    {'name': 'William J. Cassidy', 'job': 'Production Design'},
#    {'name': 'Ron Foreman', 'job': 'Art Direction'},
#    {'name': 'J. Dennis Washington', 'job': 'Art Direction'},
#    {'name': 'Joe D. Mitchell', 'job': 'Set Decoration'},
#    {'name': 'Tom Bronson', 'job': 'Costume Design'},
#    {'name': 'James D. Brubaker', 'job': 'Production Manager'},
#    {'name': 'Michael Westmore', 'job': 'Makeup Artist'},
#    {'name': 'Frank E. Warner', 'job': 'Sound Editor'},
#    {'name': 'Howard Jensen', 'job': 'Special Effects'},
#    {'name': 'Ron Stein', 'job': 'Stunt Coordinator'},
#    {'name': 'Freddie Hice', 'job': 'Stunts'}],
#   'director': ['Sylvester Stallone',
#    'Sylvester Stallone',
#    'Sylvester Stallone'],
#   'keywords': ['boxer',
#    'boxingmatch',
#    'challeng',
#    'comeback',
#    'defeat',
#    'dyinganddeath',
#    'fame',
#    'rematch',
#    'reveng',
#    'sport',
#    'train',
#    'trainer',
#    'transport',
#    'victori',
#    'wealth',
#    'worldchampion'],
#   'tmdbId': 1371,
#   'description': 'The greatest challenge. Now the world champion, Rocky Balboa is living in luxury and only fighting opponents who pose no threat to him in the ring. His lifestyle of wealth and idleness is shaken when a powerful young fighter known as Clubber Lang challenges him to a bout. After taking a pounding from Lang, the humbled champ turns to former bitter rival Apollo Creed to help him regain his form for a rematch with Lang.',
#   'meta_factor': [-0.055150892585515976,
#    0.047794852405786514,
#    -0.03984452039003372,
#    -0.005672705825418234,
#    -0.04438750445842743,
#    0.09291702508926392,
#    0.046660520136356354,
#    0.00869741477072239,
#    -0.005623930599540472,
#    -0.025853946805000305,
#    -0.028834842145442963,
#    -0.09695407748222351,
#    -0.021822791546583176,
#    0.03605285659432411,
#    -0.040079835802316666,
#    0.041739415377378464,
#    0.048925094306468964,
#    0.07041037082672119,
#    0.013104233890771866,
#    -0.07350455224514008,
#    -0.03346051275730133,
#    0.01470740232616663,
#    -0.011781489476561546,
#    0.07614050805568695,
#    -0.032548028975725174,
#    0.035827361047267914,
#    -0.037439875304698944,
#    0.00500409584492445,
#    -0.009826643392443657,
#    -0.057624395936727524,
#    0.029856398701667786,
#    -0.003056266577914357,
#    0.04513917863368988,
#    -0.0030943145975470543,
#    -0.06341864913702011,
#    -0.04050412401556969,
#    -0.04887588322162628,
#    0.02956310100853443,
#    0.0034167724661529064,
#    -0.0008785799145698547,
#    -0.030952926725149155,
#    -0.012663891538977623,
#    -0.01858597807586193,
#    -0.06095912307500839,
#    0.08007951080799103,
#    -0.06994551420211792,
#    -0.022148512303829193,
#    0.01714380271732807,
#    0.0607326366007328,
#    0.0017333999276161194,
#    0.0013901665806770325,
#    -0.03983726352453232,
#    -0.01376884151250124,
#    0.04557164013385773,
#    0.03658171743154526,
#    -0.010290319100022316,
#    0.016791637986898422,
#    {'name': 'Irwin Winkler', 'job': 'Producer'},
#    {'name': 'Bill Conti', 'job': 'Original Music Composer'},
#    {'name': 'Steven Poster', 'job': 'Director of Photography'},
#    {'name': 'John G. Avildsen', 'job': 'Editor'},
#    {'name': 'Robert A. Ferretti', 'job': 'Editor'},
#    {'name': 'Michael N. Knue', 'job': 'Editor'},
#    {'name': 'Caro Jones', 'job': 'Casting'},
#    {'name': 'William J. Cassidy', 'job': 'Production Design'},
#    {'name': 'William J. Durrell Jr.', 'job': 'Art Direction'},
#    {'name': 'John M. Dwyer', 'job': 'Set Decoration'},
#    {'name': 'Sugar Blymyer', 'job': 'Hairstylist'},
#    {'name': 'Katalin Elek', 'job': 'Makeup Artist'},
#    {'name': 'Michael S. Glick', 'job': 'Unit Production Manager'},
#    {'name': 'Stu Bernstein', 'job': 'Supervising Sound Effects Editor'},
#    {'name': 'Alan Bromberg', 'job': 'Sound Effects Editor'},
#    {'name': 'Ken Johnson', 'job': 'Music Editor'},
#    {'name': 'Lou Carlucci', 'job': 'Special Effects'},
#    {'name': 'Joe Digaetano', 'job': 'Special Effects Coordinator'},
#    {'name': 'Bobby Bass', 'job': 'Stunt Coordinator'},
#    {'name': 'Mark De Alessandro', 'job': 'Stunt Double'}],
#   'director': ['John G. Avildsen', 'John G. Avildsen', 'John G. Avildsen'],
#   'keywords': ['bankrupt',
#    'boxer',
#    'boxingmatch',
#    'boxingschool',
#    'career',
#    'cataclysm',
#    'challeng',
#    'champion',
#    'disappoint',
#    'fatherfigur',
#    'fathersonrelationship',
#    'friendship',
#    'philadelphia',
#    'prais',
#    'restart',
#    'sponsorship',
#    'sport',
#    'streetriot',
#    'taxconsult',
#    'train',
#    'trainer',
#    'transport',
#    'worldchampion'],
#   'tmdbId': 1375,
#   'description': "Go for it! A lifetime of taking shots has ended Rocky's career, and a crooked accountant has left him broke. Inspired by the memory of his trainer, however, Rocky finds glory in training and takes on an up-and-coming boxer.",
#   'meta_factor': [-0.03694790601730347,
#    0.050724245607852936,
#    -0.021776897832751274,
#    0.02035382017493248,
#    -0.03719029948115349,
#    0.10931374132633209,
#    0.03539881110191345,
#    0.024695955216884613,
#    0.0014807686675339937,
#    -0.04507261514663696,
#    0.007793497759848833,
#    -0.033098116517066956,
#    -0.007179595064371824,
#    0.050574418157339096,
#    -0.020167801529169083,
#    0.01013416051864624,
#    0.03279545158147812,
#    0.022762874141335487,
#    -0.0018201377242803574,
#    -0.06108403205871582,
#    -0.04620852693915367,
#    0.039808277040719986,
#    -0.012994900345802307,
#    0.05489075556397438,
#    -0.05242199823260307,
#    0.06117643788456917,
#    -0.055508796125650406,
#    0.007268379908055067,
#    -0.020648572593927383,
#    -0.047856591641902924,
#    0.022207846865057945,
#    0.00612126849591732,
#    0.038788679987192154,
#    0.03342536836862564,
#    -0.04055709391832352,
#    -0.02880985476076603,
#    -0.054322317242622375,
#    0.09162979573011398,
#    -0.025416644290089607,
#    0.02037692442536354,
#    -0.02224981039762497,
#    -0.013790514320135117,
#    -0.020492617040872574,
#   'popularity': '1.523446',
#   'release_date': 802026000000,
#   'tagline': "She's not proper, she's not fitting, she's not British, but to Jack she's a breath of fresh air.",
#   'title': 'Jack & Sarah',
#   'vote_average': 5.1,
#   'vote_count': 10,
#   'year': 1995,
#   'cast': ['Richard E. Grant', 'Samantha Mathis', 'Judi Dench'],
#   'crew': [{'name': 'Lesley Walker', 'job': 'Editor'},
#    {'name': 'Elisabeth Leustig', 'job': 'Casting'},
#    {'name': 'Pippa Cross', 'job': 'Producer'},
#    {'name': 'Jean-Yves Escoffier', 'job': 'Director of Photography'},
#    {'name': 'Simon Boswell', 'job': 'Original Music Composer'},
#    {'name': 'Mary Gail Artz', 'job': 'Casting'},
#    {'name': 'Barbara Cohen', 'job': 'Casting'},
#    {'name': 'Simon Channing Williams', 'job': 'Producer'},
#    {'name': 'Tim Sullivan', 'job': 'Screenplay'},
#    {'name': 'Tim Sullivan', 'job': 'Director'},
#    {'name': 'Janette Day', 'job': 'Producer'},
#    {'name': 'Simone Reynolds', 'job': 'Casting'},
#    {'name': 'Christopher J. Bradshaw', 'job': 'Production Design'},
#    {'name': 'Humphrey Bangham', 'job': 'Art Direction'},
#    {'name': 'Dany Everett', 'job': 'Costume Design'},
#    {'name': 'Kate Dowd', 'job': 'Casting'},
#    {'name': 'Heather Storr', 'job': 'Script Supervisor'},
#    {'name': 'Simon Mein', 'job': 'Still Photographer'}],
#   'director': ['Tim Sullivan', 'Tim Sullivan', 'Tim Sullivan'],
#   'keywords': ['babi', 'daughter', 'depress', 'londonengland', 'nanni'],
#   'tmdbId': 2021,
#   'description': "She's not proper, she's not fitting, she's not British, but to Jack she's a breath of fresh air. Jack always lands on his feet. He lands on his feet when he marries the beautiful Sarah. He lands on his feet when he buys a luxurious new home. However, when Sarah goes into labour, he takes a tumble down the stairs and lands on his head. When he comes around he discovers he is the proud father of a baby girl, but deficient in the spouse department to the tune of 1.",
#   'meta_factor': [-0.059182822704315186,
#    -0.062453966587781906,
#    0.01654312014579773,
#    -0.032124098390340805,
#    -0.09615056216716766,
#    0.04815115034580231,
#    0.09945224970579147,
#    -0.01902870461344719,
#    0.017303645610809326,
#    0.03519851714372635,
#    -0.02127368561923504,
#    -0.04416918009519577,
#    0.012035959400236607,
#    -0.006256709340959787,
#    -0.0559590682387352,
#    0.048793233931064606,
#    0.03923201933503151,
#    0.05116574466228485,
#    0.0018384316936135292,
#    0.022385694086551666,
#    0.035854678601026535,
#    0.01738746650516987,
#    0.019432419911026955,
#    -0.008048588410019875,
#    -0.006682896055281162,
#    0.04572053998708725,
#    0.02005035988986492,
#    0.007787282112985849,
#    -0.030463341623544693,
#    -0.03586423397064209,
#    0.0054037002846598625,
#    0.07832428812980652,
#    0.04896234720945358,
#    -0.014229228720068932,
#    0.010150711983442307,
#    0.006752639077603817,
#    0.044860757887363434,
#    0.03874674439430237,
#    -0.006990509107708931,
#    0.047252461314201355,
#    -0.03293154016137123,
#    -0.06331519782543182,
#    0.015571707859635353,
#    -0.048721522092819214,
#    0.03618607297539711,
#   'popularity': '12.477872',
#   'release_date': 1165424400000,
#   'tagline': 'It will cost you everything.',
#   'title': 'Blood Diamond',
#   'vote_average': 7.4,
#   'vote_count': 2344,
#   'year': 2006,
#   'cast': ['Leonardo DiCaprio', 'Djimon Hounsou', 'Jennifer Connelly'],
#   'crew': [{'name': 'Dan Weil', 'job': 'Production Design'},
#    {'name': 'Harry Cohen', 'job': 'Sound Effects Editor'},
#    {'name': 'Victoria Thomas', 'job': 'Casting'},
#    {'name': 'James Newton Howard', 'job': 'Original Music Composer'},
#    {'name': 'Ngila Dickson', 'job': 'Costume Design'},
#    {'name': 'Charles Leavitt', 'job': 'Screenplay'},
#    {'name': 'Charles Leavitt', 'job': 'Story'},
#    {'name': 'Steven Rosenblum', 'job': 'Editor'},
#    {'name': 'Moonyeenn Lee', 'job': 'Casting'},
#    {'name': 'Sallie Jaye', 'job': 'Makeup Department Head'},
#    {'name': 'Neil Corbould', 'job': 'Special Effects'},
#    {'name': 'Ben Waisbren', 'job': 'Executive Producer'},
#    {'name': 'Edward Zwick', 'job': 'Director'},
#    {'name': 'Edward Zwick', 'job': 'Producer'},
#    {'name': 'Marshall Herskovitz', 'job': 'Producer'},
#    {'name': 'Tim Monich', 'job': 'Dialect Coach'},
#    {'name': 'Curtis Lindersmith', 'job': 'Digital Intermediate'},
#    {'name': 'Christopher Assells', 'job': 'Sound Effects Editor'},
#    {'name': 'William Mesa', 'job': 'Visual Effects Supervisor'},
#    {'name': 'Gillian Gorfil', 'job': 'Producer'},
#    {'name': 'Graham King', 'job': 'Producer'},
#    {'name': 'Darrell James Roodt', 'job': 'Producer'},
#    {'name': 'Paula Weinstein', 'job': 'Producer'},
#    {'name': 'Eduardo Serra', 'job': 'Director of Photography'},
#    {'name': 'Peter Wenham', 'job': 'Supervising Art Director'},
#    {'name': 'Olivia Bloch-Lainé', 'job': 'Set Decoration'},
#    {'name': 'Sharon Martin', 'job': 'Hairstylist'},
#    {'name': 'Lon Bender', 'job': 'Supervising Sound Editor'},
#    {'name': 'Jim Weidman', 'job': 'Music Editor'},
#    {'name': 'Romulo Adriano Jr.', 'job': 'Visual Effects'},
#    {'name': 'Jeffrey A. Okun', 'job': 'Visual Effects Supervisor'},
#    {'name': 'Francois Grobbelaar', 'job': 'Stunt Double'},
#    {'name': "Mick 'Stuntie' Milligan", 'job': 'Stunt Double'},
#    {'name': 'Paul Jennings', 'job': 'Stunt Coordinator'},
#    {'name': 'Len Amato', 'job': 'Executive Producer'},
#    {'name': 'Genevieve Hofmeyr', 'job': 'Producer'},
#    {'name': 'Kevin De La Noy', 'job': 'Executive Producer'},
#    {'name': 'C. Gaby Mitchell', 'job': 'Story'},
#    {'name': 'Tony Clark', 'job': 'Visual Effects Supervisor'},
#    {'name': 'Daran Fulham', 'job': 'Art Direction'},
#    {'name': 'Ray Chan', 'job': 'Supervising Art Director'},
#    {'name': 'John Roesch', 'job': 'Foley'},
#    {'name': 'Josh Gummersall', 'job': 'Producer'},
#    {'name': 'Philip Key', 'job': 'Producer'},
#    {'name': 'Rae Donnelly', 'job': 'Costume Supervisor'},
#    {'name': 'Pip Lingard', 'job': 'Costume Supervisor'},
#    {'name': 'Klemens Becker', 'job': 'Camera Operator'},
#    {'name': 'Paul Hedges', 'job': 'Property Master'},
#    {'name': 'Mark Hardy', 'job': 'Transportation Coordinator'},
#    {'name': 'Andy Nelson', 'job': 'Sound Re-Recording Mixer'},
#    {'name': 'Jana Chovancova', 'job': 'Art Department Coordinator'},
#    {'name': 'Jon Title', 'job': 'Sound Designer'},
#    {'name': 'David Olson', 'job': 'Music Editor'},
#    {'name': 'Jayne-Ann Tenggren', 'job': 'Script Supervisor'},
#    {'name': 'Karen Vassar Triest', 'job': 'Sound Effects Editor'},
#    {'name': 'John C. Stuver', 'job': 'Dialogue Editor'},
#    {'name': 'Jay B. Richardson', 'job': 'Music Editor'},
#    {'name': 'Blake R. Cornett', 'job': 'Sound Recordist'},
#    {'name': 'Emily Wallin', 'job': 'Visual Effects Producer'},
#    {'name': 'Clive Pollick', 'job': 'Construction Coordinator'},
#    {'name': 'Mick Snell', 'job': 'Location Manager'},
#    {'name': 'George Macri', 'job': 'Visual Effects Producer'},
#    {'name': 'Ray McIntyre Jr.', 'job': 'Visual Effects Supervisor'},
#    {'name': 'Jaap Buitendijk', 'job': 'Still Photographer'},
#    {'name': 'Alex Meddick', 'job': 'Visual Effects Editor'},
#    {'name': 'Gregory D. Liegey', 'job': 'Visual Effects Supervisor'},
#    {'name': 'Alyson Dee Moore', 'job': 'Foley'},
#    {'name': 'Anna Behlmer', 'job': 'Sound Re-Recording Mixer'},
#    {'name': 'Nick Turnbull', 'job': 'Property Master'},
#    {'name': 'Alan Shearer', 'job': 'Production Manager'},
#    {'name': 'Sarah Moudjebeur', 'job': 'Assistant Art Director'},
#    {'name': 'Liz van den Berg', 'job': 'Scenic Artist'},
#    {'name': 'Andy Garner', 'job': 'Sculptor'},
#    {'name': 'Laura Harris Atkinson', 'job': 'Dialogue Editor'},
#    {'name': 'Pamela Kahn', 'job': 'Foley'},
#    {'name': 'Damien Smith', 'job': 'Foley'},
#    {'name': 'Kerry Dean Williams', 'job': 'ADR & Dubbing'},
#    {'name': 'Thomas Boland', 'job': 'Visual Effects Producer'},
#    {'name': 'Neil Greenberg', 'job': 'Visual Effects Editor'},
#    {'name': 'Leigh Mackenzie', 'job': 'Camera Operator'},
#    {'name': 'Mike Proudfoot', 'job': 'Camera Operator'},
#    {'name': 'Sarel Pretorius', 'job': 'Steadicam Operator'},
#    {'name': 'Adam Dale', 'job': 'Helicopter Camera'},
#    {'name': 'Donnie Creighton', 'job': 'Digital Intermediate'},
#    {'name': 'Brian Baverstock', 'job': 'Transportation Coordinator'},
#    {'name': 'Paul Fisher', 'job': 'Transportation Coordinator'},
#    {'name': 'Rob Harris', 'job': 'Unit Publicist'}],
#   'director': ['Edward Zwick', 'Edward Zwick', 'Edward Zwick'],
#   'keywords': ['bootlegg',
#    'diamondmin',
#    'fisherman',
#    'genocideinrwanda',
#    'journal',
#    'journalist',
#    'lossoffamili',
#    'mercenari',
#    -0.05195663124322891,
#    -0.00039224931970238686,
#    0.05596606433391571,
#    -0.006867329590022564,
#    0.09792058169841766,
#    -0.002464005257934332,
#    0.039083026349544525,
#    0.019061405211687088,
#    0.029260076582431793,
#    -0.03219010308384895,
#    0.04454702138900757,
#    -0.04031926393508911,
#    0.04631786793470383,
#    -0.036079518496990204,
#    -0.04265901818871498,
#    -0.00018782168626785278,
#    0.0279095359146595,
#    0.0015882329316809773,
#    -0.04146295040845871,
#    -0.006503976881504059,
#    -0.005968879908323288,
#    -0.008786248043179512,
#    0.023945067077875137,
#    0.019275270402431488,
#    0.04021463915705681,
#    0.022260814905166626,
#    0.00533114280551672,
#    -0.01309856679290533,
#    -0.019231176003813744,
#    -0.05842513591051102,
#    0.00985032133758068,
#    -0.013259446248412132,
#    0.0074150450527668,
#    0.04760068282485008,
#    0.023098010569810867,
#    -0.023529868572950363,
#    -0.11191694438457489,
#    0.02262718603014946,
#    -0.015924392268061638,
#    -0.029352135956287384,
#    -0.04249194264411926,
#    0.004999636672437191,
#    -0.05084739625453949,
#    -0.006896711885929108,
#    -0.05804440379142761,
#    -0.03464672714471817,
#    -0.0006371266208589077,
#    0.03437792509794235,
#    0.03923426941037178,
#    0.07701481133699417,
#    -0.06229345127940178,
#    -0.015979500487446785,
#    0.023317549377679825,
#    -0.031399913132190704,
#    0.035665035247802734,
#    0.054209642112255096,
#    -0.020359035581350327,
#    -0.02618333324790001,
#    -0.0405573844909668],
#   'model_timestamp': 1734864075,
#   'model_version': 'ALS_53272c9f13ec',
#   'model_factor': [0.166366,
#    0.35602126,
#    0.1729225,
#    0.19406794,
#    0.03127336,
#    0.048346873,
#    0.14133686,
#    0.47042122,
#    0.37045568,
#    0.15935716,
#    0.0,
#    0.05177037,
#    0.0013978886,
#    0.8513153,
#    0.06551933,
#    0.33441573,
#    0.12816522,
#    0.0,
#    0.57795215,
#    0.23125032],
#   'score': 0.333729925},
#  {'movieId': 1722,
#   'genres': ['Drama', 'History', 'Romance'],
#   'id': 1722,
#   'overview': 'When a Greek fisherman leaves to fight with the Greek army during WWII, his fiancee falls in love with the local Italian commander. The film is based on a novel about an Italian soldier\'s experiences during the Italian occupation of the Greek island of Cephalonia (Kefalonia), but Hollywood made it into a pure love story by removing much of the "unpleasant" stuff.',
#   'popularity': '9.243715',
#   'release_date': 997981200000,
#   'tagline': '',
#   'title': "Captain Corelli's Mandolin",
#   'vote_average': 5.6,
#   'vote_count': 146,
#   'year': 2001,
#   'cast': ['Nicolas Cage', 'Penélope Cruz', 'John Hurt'],
#   'crew': [{'name': 'Mick Audsley', 'job': 'Editor'},
#    {'name': 'Stephen Warbeck', 'job': 'Original Music Composer'},
#    {'name': 'Mary Selway', 'job': 'Casting'},
#    {'name': 'Jim Clay', 'job': 'Production Design'},
#    {'name': 'Tim Bevan', 'job': 'Producer'},
#    {'name': 'Eric Fellner', 'job': 'Producer'},
#    {'name': 'John Toll', 'job': 'Director of Photography'},
#    {'name': 'Mark Huffam', 'job': 'Producer'},
#    {'name': 'Shawn Slovo', 'job': 'Screenplay'},
#    {'name': 'John Madden', 'job': 'Director'},
#    -0.07826536893844604,
#    -0.08334478735923767,
#    0.02714008465409279,
#    0.020509110763669014,
#    -0.011866537854075432,
#    -0.0035223327577114105,
#    0.03996249660849571,
#    -0.027472741901874542,
#    0.019237007945775986,
#    -0.04297478497028351,
#    -0.010052625089883804,
#    0.0005973181687295437,
#    0.07573723047971725,
#    -0.03957865387201309,
#    -0.06523370742797852,
#    -0.04057712107896805,
#    0.015010306611657143,
#    -0.01670391857624054,
#    0.04092133790254593,
#    0.028549043461680412,
#    -0.007968682795763016,
#    0.03678019344806671,
#    -0.016400154680013657,
#    0.056194595992565155,
#    -0.04817122966051102,
#    -0.004762678872793913,
#    0.0007977657951414585,
#    0.001567601109854877,
#    0.011035129427909851,
#    0.0420573428273201,
#    0.044440917670726776,
#    0.018741708248853683,
#    0.030384577810764313,
#    0.04834992438554764,
#    0.10391443967819214,
#    0.025765366852283478,
#    0.02261210046708584,
#    -0.036396726965904236,
#    0.011436713859438896,
#    0.03358126059174538,
#    -0.02215154469013214],
#   'model_timestamp': 1734864075,
#   'model_version': 'ALS_53272c9f13ec',
#   'model_factor': [0.24802968,
#    0.10719171,
#    0.11845708,
#    0.0995717,
#    0.12714766,
#    0.055202447,
#    0.34214672,
#    0.07374556,
#    0.16968003,
#    0.14883623,
#    0.06712373,
#    0.18222238,
#    0.19429806,
#    1.0110353,
#    0.0,
#    0.32406372,
#    0.159289,
#    0.0,
#    0.4672548,
#    0.04371676],
#   'score': 0.33349435}]

# %%
from IPython.core.display import HTML, Image


def get_movies_for_user(the_id, num=10, ratings="ratings", movies="movies"):
    response = es.search(index=ratings, q="userId:{}".format(
        the_id), size=num, sort=["rating:desc"])
    hits = response['hits']['hits']
    ids = [h['_source']['movieId'] for h in hits]
    movies = es.mget(body={"ids": ids}, index=movies,
                     _source_includes=['tmdbId', 'title'])
    movies_hits = movies['docs']
    tmdbids = [h['_source'] for h in movies_hits]
    return tmdbids


def display_user_recs(the_id, q="*", num=10, num_last=10, users="users", movies="movies", ratings="ratings"):
    user, recs = get_user_recs(the_id, q, num, users, movies)
    user_movies = get_movies_for_user(the_id, num_last, ratings, movies)
    # check that posters can be displayed
    first_movie = user_movies[0]
    first_im_url = get_poster_url(first_movie['tmdbId'])
    if first_im_url == "NA":
        display(
            HTML("<i>Cannot import tmdbsimple. No movie posters will be displayed!</i>"))
    if first_im_url == "KEY_ERR":
        display(HTML(
            "<i>Key error accessing TMDb API. Check your API key. No movie posters will be displayed!</i>"))

    # display the movies that this user has rated highly
    display(HTML("<h2>Get recommended movies for user id %s</h2>" % the_id))
    display(HTML("<h4>The user has rated the following movies highly:</h4>"))
    user_html = "<table border=0>"
    i = 0
    for movie in user_movies:
        movie_im_url = get_poster_url(movie['tmdbId'])
        movie_title = movie['title']
        user_html += "<td><h5>%s</h5><img src=%s width=150></img></td>" % (
            movie_title, movie_im_url)
        i += 1
        if i % 5 == 0:
            user_html += "</tr><tr>"
    user_html += "</tr></table>"
    display(HTML(user_html))
    # now display the recommended movies for the user
    display(HTML("<br>"))
    display(HTML("<h2>Recommended movies:</h2>"))
    rec_html = "<table border=0>"
    i = 0
    for rec in recs:
        r_im_url = get_poster_url(rec['_source']['tmdbId'])
        r_score = rec['_score']
        r_title = rec['_source']['title']
        rec_html += "<td><h5>%s</h5><img src=%s width=150></img></td><td><h5>%2.3f</h5></td>" % (
            r_title, r_im_url, r_score)
        i += 1
        if i % 5 == 0:
            rec_html += "</tr><tr>"
    rec_html += "</tr></table>"
    display(HTML(rec_html))


def display_similar(the_id, q="*", num=10, movies="movies"):
    """
    Display query movie, together with similar movies and similarity scores, in a table
    """
    movie, recs = get_similar(the_id, q, num, movies)
    q_im_url = get_poster_url(movie['tmdbId'])
    if q_im_url == "NA":
        display(
            HTML("<i>Cannot import tmdbsimple. No movie posters will be displayed!</i>"))
    if q_im_url == "KEY_ERR":
        display(HTML(
            "<i>Key error accessing TMDb API. Check your API key. No movie posters will be displayed!</i>"))

    display(HTML("<h2>Get similar movies for:</h2>"))
    display(HTML("<h4>%s</h4>" % movie['title']))
    display(HTML("<p>%s</p>" % movie['description']))
    if q_im_url != "NA":
        display(Image(q_im_url, width=200))
    display(HTML("<br>"))
    display(HTML("<h2>People who liked this movie also liked these:</h2>"))
    sim_html = "<table border=0>"
    i = 0
    for rec in recs:
        r_im_url = get_poster_url(rec['_source']['tmdbId'])
        r_score = rec['_score']
        r_title = rec['_source']['title']
        sim_html += "<td><h5>%s</h5><img src=%s width=150></img></td><td><h5>%2.3f</h5></td>" % (
            r_title, r_im_url, r_score)
        i += 1
        if i % 5 == 0:
            sim_html += "</tr><tr>"
    sim_html += "</tr></table>"
    display(HTML(sim_html))

# %%
from run_eval import evaluate_hybrid_recommender, evaluate_user_recommender, evaluate_similar_recommender
import numpy as np
import matplotlib.pyplot as plt

alphas = [0.3, 0.5, 0.7]
metrics = ['coverage', 'diversity', 'novelty']

for alpha in alphas:
    hybrid_results = evaluate_hybrid_recommender(es=es, alpha=alpha)
    user_results = evaluate_user_recommender(es=es)
    similar_results = evaluate_similar_recommender(es=es)

    data = {
        'Hybrid': [hybrid_results[metric] for metric in metrics],
        'Collaborative': [user_results[metric] for metric in metrics],
        'Content-based': [similar_results[metric] for metric in metrics]
    }

    x = np.arange(len(metrics))
    width = 0.25
    multiplier = 0

    fig, ax = plt.subplots(figsize=(10, 6))
    for recommender, measurement in data.items():
        offset = width * multiplier
        rects = ax.bar(x + offset, measurement, width, label=recommender)
        multiplier += 1

    ax.set_ylabel('Score')
    ax.set_title(f'Comparison of Recommender Systems (Alpha={alpha})')
    ax.set_xticks(x + width, metrics)
    ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
    ax.set_ylim(0, 1)

    for rect in ax.patches:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., height,
                f'{height:.2f}',
                ha='center', va='bottom')

    plt.tight_layout()
    file_name = f'recommender_comparison_alpha_{alpha}.png'
    plt.savefig(file_name)
    print(f'Chart saved as {file_name}')
    plt.close(fig)
# Out:
# Chart saved as recommender_comparison_alpha_0.3.png
# Chart saved as recommender_comparison_alpha_0.5.png
# Chart saved as recommender_comparison_alpha_0.7.png
